# %% [markdown]
# # Customer Segmentation
# Bu projede bir şirketin, hedeflenen pazarlamaya yardımcı olmak ve satın alma alışkanlıklarını anlamak için müşterilerin sınıflandırılmasını içermektedir.
# <br><br>
# Veri seti aşağıdaki tablolardan oluşmaktadır:
# * Müşteri
# * Ürünler
# * Siparişler

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("PBL5recommendationdata.csv", encoding='latin-1')

# %%
df.head()
# Out:
#    Customers.id Customers.fname Customers.lname Customers.company  \
# 0           797         Christy            Dill          Company0
# 1             3            John           Smith          Company1
# 2             3            John           Smith          Company1
# 3             4           James        Anderson               NaN
# 4             5         Abraham          Pollak          Company3
#
#    Customers.create_date  Customers.status  Customers.mailing  \
# 0             1426018724               NaN                NaN
# 1             1386089139               NaN                NaN
# 2             1386089139               NaN                NaN
# 3             1386780263               NaN                NaN
# 4             1386861599               0.0                0.0
#
#    Customers.reminders  Customers.tax_exempt  Customers.account_id  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
# 3                  NaN                   NaN                   NaN
# 4                  NaN                   NaN                   NaN
#
#    Customers.sales_rep  Customers.rewards  Customers.profile_id  \
# 0                  NaN                NaN                   NaN
# 1                  NaN                NaN                   NaN
# 2                  NaN                NaN                   NaN
# 3                  NaN                NaN                   NaN
# 4                  NaN                NaN                   NaN
#
#    Customers.last_modified  Customers.customer_type  Orders.id  \
# 0               1437764306                      0.0       3758
# 1               1437764354                      0.0         23
# 2               1437764354                      0.0       9531
# 3               1437762646                      0.0         29
# 4               1437764316                      0.0         30
#
#    Orders.customer_id Orders.fname Orders.lname Orders.company  \
# 0                 797      Christy         Dill       Company0
# 1                   3         John        Smith       Company1
# 2                   3         John        Smith       Company1
# 3                   4        James     Anderson            NaN
# 4                   5      Abraham       Pollak       Company3
#
#   Orders.order_number  Orders.reorder_id Orders.external_source  \
# 0                3758                NaN                    NaN
# 1                  23                NaN                    NaN
# 2                9531                NaN                    NaN
# 3                  29                NaN                   Ebay
# 4                  30                NaN                    NaN
#
#    Orders.external_id Orders.currency  Orders.sales_rep  Orders.subtotal  \
# 0                 NaN             USD               NaN            57.20
# 1                 NaN             USD               NaN            20.00
# 2                 NaN             USD               NaN            68.78
# 3                 NaN             USD               NaN            19.56
# 4                 NaN             USD               NaN            36.05
#
#    Orders.tax  Orders.shipping  Orders.coupon_id  Orders.coupon_amount  \
# 0         0.0             9.95              13.0                  2.86
# 1         NaN             9.99               NaN                   NaN
# 2         0.0             9.95               NaN                   NaN
# 3         0.0             9.95               NaN                   NaN
# 4         NaN             9.95               NaN                   NaN
#
#    Orders.gift_id  Orders.gift_amount Orders.fee_name  Orders.fee_amount  \
# 0             NaN                 NaN             NaN                NaN
# 1             NaN                 NaN             NaN                NaN
# 2             NaN                 NaN             NaN                NaN
# 3             NaN                 NaN             NaN               0.04
# 4             NaN                 NaN             NaN                NaN
#
#   Orders.discount_name  Orders.discount_amount  Orders.total  \
# 0                  NaN                     NaN         64.29
# 1                  NaN                     NaN         29.99
# 2                  NaN                     NaN         78.73
# 3                  NaN                     NaN         29.55
# 4                  NaN                     NaN         46.00
#
#    Orders.balance_due Orders.shipping_carrier Orders.shipping_method  \
# 0                 NaN                   fedex              11|Ground
# 1                 NaN                   fedex              11|Ground
# 2                 NaN                  manual    0|Standard Shipping
# 3                 NaN                     NaN              11|Ground
# 4                 NaN                   fedex              11|Ground
#
#    Orders.shipping_trans  Orders.shipping_flags  Orders.weight  \
# 0                    NaN                    NaN            NaN
# 1                    NaN                    NaN            NaN
# 2                    NaN                    NaN            NaN
# 3                    NaN                    NaN            NaN
# 4                    NaN                    NaN            NaN
#
#   Orders.tracking  Orders.payment_status  Orders.payment_date  \
# 0      5.7204E+14                    3.0         1.426019e+09
# 1     1.28597E+14                    3.0         1.386090e+09
# 2             NaN                    3.0         1.449604e+09
# 3     7.96468E+14                    3.0         1.386780e+09
# 4     6.87398E+14                    3.0         1.386862e+09
#
#   Orders.payment_user Orders.payment_type Orders.payment_method  \
# 0                 NaN       authorize.net                   NaN
# 1                 NaN       authorize.net                   NaN
# 2           genlee166       authorize.net                   NaN
# 3                 NaN                 NaN           Credit Card
# 4                 NaN                 NaN           Credit Card
#
#    Orders.payment_amount  Orders.purchase_order Orders.payment_id  \
# 0                  64.29                    NaN        6993607863
# 1                  29.99                    NaN                 0
# 2                  78.73                    NaN                 0
# 3                  29.55                    NaN               NaN
# 4                  46.00                    NaN               NaN
#
#   Orders.payment_code  Orders.payment_ref  Orders.status  Orders.placed_date  \
# 0              510142                 NaN              1          1426019099
# 1                   0                 NaN              1          1386090455
# 2                   0                 NaN              3          1449603652
# 3                 NaN                 NaN              1          1386780263
# 4                 NaN                 NaN              1          1386861599
#
#    Orders.updated_date  Orders.shipped_date              Orders.comments  \
# 0         1.438868e+09         1.426101e+09                          NaN
# 1         1.440529e+09         1.386103e+09                          NaN
# 2         1.450213e+09                  NaN                   test order
# 3         1.440529e+09         1.386800e+09  ebay order\rpaid by pay pal
# 4         1.440529e+09         1.386876e+09                          NaN
#
#            Orders.notes  Orders.registry_id  Orders.gift_message  \
# 0  Insured By Eye4Fraud                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                  Test                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    Orders.website  Orders.mailing  Orders.flags  Orders.partial_ship  \
# 0             NaN             NaN           NaN                  NaN
# 1             NaN             NaN           NaN                  NaN
# 2             NaN             NaN           NaN                  NaN
# 3             NaN             NaN           NaN                  NaN
# 4             NaN             NaN           NaN                  NaN
#
#    Orders.customer_type  Order_Items.id  Order_Items.parent  \
# 0                   0.0            5284                3758
# 1                   0.0              31                  23
# 2                   0.0           11655                9531
# 3                   0.0            1816                  29
# 4                   0.0              40                  30
#
#    Order_Items.product_id                       Order_Items.product_name  \
# 0                  2310.0                         Basic Rollators, Green
# 1                   177.0                       Urinary Drain Bags,0.000
# 2                     1.0  SensiCare Nitrile Exam Gloves, Blue, XX-Large
# 3                   983.0                    Basket for 2-Button Walkers
# 4                   991.0                                     Tens Units
#
#    Order_Items.attributes Order_Items.attribute_names  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#    Order_Items.attribute_prices  Order_Items.qty  Order_Items.price  \
# 0                           NaN                1              57.20
# 1                           NaN                4               5.00
# 2                           NaN                1              68.78
# 3                           NaN                1              19.56
# 4                           NaN                1              36.05
#
#    Order_Items.cost  Order_Items.registry_item  Order_Items.related_id  \
# 0             44.00                        NaN                     NaN
# 1              1.87                        NaN                     NaN
# 2             52.50                        NaN                     NaN
# 3             12.62                        NaN                     NaN
# 4             25.75                        NaN                     NaN
#
#    Order_Items.reorder_frequency  Order_Items.account_id  Order_Items.flags  \
# 0                            NaN                     NaN                NaN
# 1                            NaN                     NaN                2.0
# 2                            NaN                     NaN                NaN
# 3                            NaN                     NaN                NaN
# 4                            NaN                     NaN                NaN
#
#    Products.id  Products.status  Products.product_type  \
# 0       2310.0              0.0                    NaN
# 1        177.0              1.0                    NaN
# 2          1.0              0.0                    NaN
# 3        983.0              0.0                    NaN
# 4        991.0              1.0                    NaN
#
#          Products.template  Products.vendor  Products.import_id  \
# 0  sub-product-detail.html              1.0                 3.0
# 1  sub-product-detail.html              1.0                 3.0
# 2  sub-product-detail.html              1.0                 3.0
# 3  sub-product-detail.html              1.0                 3.0
# 4  sub-product-detail.html              1.0                 3.0
#
#                                  Products.name  \
# 0                  Basic Steel Rollators,Green
# 1                           Urinary Drain Bags
# 2  SensiCare Nitrile Exam Gloves,Blue,XX-Large
# 3                  Basket for 2-Button Walkers
# 4                        TENS 3000 Analog Unit
#
#                                Products.display_name  Products.menu_name  \
# 0  Basic Lightweight Rollators For Adults, With S...                 NaN
# 1                                 Urinary Drain Bags                 NaN
# 2      SensiCare Nitrile Exam Gloves, Blue, XX-Large                 NaN
# 3                        Basket for 2-Button Walkers                 NaN
# 4                              TENS 3000 Analog Unit                 NaN
#
#    Products.list_price  Products.price  Products.sale_price  Products.cost  \
# 0                80.70           57.64                  NaN          44.00
# 1                14.41           10.29                  5.0           1.87
# 2                96.29           68.78                  NaN          52.50
# 3                27.38           19.56                  NaN          12.62
# 4                50.47           36.05                  NaN          25.75
#
#    Products.flags  Products.left_flag  Products.right_flag  \
# 0             0.0                 NaN                  NaN
# 1            65.0                 NaN                  NaN
# 2         32896.0                 NaN                  NaN
# 3             0.0                 NaN                  NaN
# 4             0.0                 NaN                  NaN
#
#    Products.last_modified  Products.taxable  Products.shopping_gtin  \
# 0            1.463163e+09               1.0            1.088440e+13
# 1            1.462370e+09               1.0            1.008020e+13
# 2            1.463163e+09               1.0            4.008020e+13
# 3            1.462595e+09               1.0                     NaN
# 4            1.462370e+09               1.0                     NaN
#
#   Products.shopping_brand Products.shopping_mpn Products.shopping_gender  \
# 0                 MEDLINE           MDS86850EGS                      NaN
# 1                 MEDLINE             DYNC1674H                      NaN
# 2                 MEDLINE                484805                      NaN
# 3                 MEDLINE            MDS86615KH                      NaN
# 4      ROSCOE MEDICAL INC              MDS86710                      NaN
#
#   Products.shopping_color Products.shopping_age  Products.shopping_flags  \
# 0                   Green                   NaN                     62.0
# 1                     NaN                   NaN                     62.0
# 2                    Blue                   NaN                     62.0
# 3                     NaN                   NaN                     62.0
# 4                     NaN                   NaN                     62.0
#
#   Products.amazon_asin  Products.amazon_type Products.amazon_item_type  \
# 0           B00I6GQE0A                   NaN      health-care-products
# 1           B000QF7Y76                   NaN      health-care-products
# 2           B002209AOI                   NaN      health-care-products
# 3           B00083DG00                   NaN      health-care-products
# 4                  NaN                   NaN      health-care-products
#
#    Products.amazon_price      Products.google_shopping_id  \
# 0                    NaN  generic/online%3Aen%3AUS%3A2310
# 1                    NaN                              NaN
# 2                    NaN     generic/online%3Aen%3AUS%3A1
# 3                    NaN                              NaN
# 4                    NaN                              NaN
#
#                        Products.google_shopping_type  \
# 0    Walking Aids > Rollators, & Walkers > Rollators
# 1  Incontinence, Urology & Ostomy > Urology > Dra...
# 2  Apparel > Gloves > Nonsterile PF LF Synthetic ...
# 3  Walking Aids > Rollators, & Walkers > Walkers ...
# 4   Physical Therapy > Electronic Muscle Stimulation
#
#     Products.google_shopping_cat  Products.google_adwords  \
# 0  Health & Beauty > Health Care                      NaN
# 1  Health & Beauty > Health Care                      NaN
# 2  Health & Beauty > Health Care                      NaN
# 3  Health & Beauty > Health Care                      NaN
# 4  Health & Beauty > Health Care                      NaN
#
#    Products.shopping_cat Products.shopping_type  \
# 0                    NaN                    NaN
# 1                  199.0          Miscellaneous
# 2                  199.0          Miscellaneous
# 3                  199.0          Miscellaneous
# 4                  199.0          Miscellaneous
#
#                            Products.pricegrabber_cat  Products.shopzilla_cat  \
# 0                                                NaN                     NaN
# 1  Health & Beauty > Medical Supplies > Medical Aids                 22005.0
# 2  Health & Beauty > Medical Supplies > Medical Aids                 22005.0
# 3  Health & Beauty > Medical Supplies > Medical Aids                 22005.0
# 4  Health & Beauty > Medical Supplies > Medical Aids                 22005.0
#
#                                 Products.thefind_cat Products.quickbooks_id  \
# 0                                                NaN    8000064C-1434298761
# 1  Health & Beauty > Medical Supplies > Medical Aids    80008C35-1438901283
# 2  Health & Beauty > Medical Supplies > Medical Aids    800087BB-1438898332
# 3  Health & Beauty > Medical Supplies > Medical Aids    8000065E-1434298780
# 4  Health & Beauty > Medical Supplies > Medical Aids    80008B12-1438900627
#
#    Products.qb_edit_sequence  Products.price_break_type  \
# 0               1.450325e+09                        NaN
# 1               1.450322e+09                        NaN
# 2               1.450321e+09                        NaN
# 3               1.450323e+09                        NaN
# 4               1.450323e+09                        NaN
#
#    Products.price_breaks                Products.short_description  \
# 0                    NaN             ROLLATOR,BASIC,STEEL,6",GREEN
# 1                    NaN   BAG,DRAINAGE,UROLOGY,2000ML,ANTI REFLUX
# 2                    NaN  GLOVE,EXAM,NITRILE,BLUE,FINGRTIP,TXT,XXL
# 3                    NaN           BASKET,WALKER,FOR 2 BUTTON WALK
# 4                    NaN        DEVICE,TENS UNIT,TENS 1000,DUAL CH
#
#                            Products.long_description  Products.websites  \
# 0  <ul><li>  Classically designed, value priced</...                NaN
# 1  <ul><li>  Only Medline drain bags have a slide...                NaN
# 2  <ul><li> SensiCare&reg; nitrile exam gloves fe...                NaN
# 3  <ul><li> This wire basket attaches to almost a...                NaN
# 4  <ul><li> The TENS 3000<sup>TM</sup> analog uni...                NaN
#
#   Products.video  Products.audio  \
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
#
#                                   Products.seo_title Products.seo_description  \
# 0  Basic Lightweight Rollators For Adults, With S...                      NaN
# 1           Urinary Drain Bags | MEDLINE - DYNC1674H                      NaN
# 2  Nitrile Exam Gloves, Blue, XX-Large | MEDLINE ...                      NaN
# 3  Basket for 2-Button Walkers | MEDLINE - MDS866...                      NaN
# 4  TENS 3000 Analog Unit | ROSCOE MEDICAL INC - M...                      NaN
#
#   Products.seo_keywords Products.seo_header  Products.seo_footer  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#                                     Products.seo_url  Products.seo_category  \
# 0  Basic-Rollators-For-Adults-With-Seat-Green-6-W...                    0.0
# 1                             Urinary-Drain-Bags0000                    0.0
# 2          SensiCare-Nitrile-Exam-GlovesBlueXX-Large                    0.0
# 3                      Basket-for-2-Button-Walkers-2                    0.0
# 4                                         Tens-Units                    0.0
#
#   Products.unit Products.packaging Products.display_packaging  \
# 0            EA      1 Each / Each                        NaN
# 1            EA      1 Each / Each                        NaN
# 2            CS    800 Each / Case                        NaN
# 3            EA      1 Each / Each                        NaN
# 4            EA      1 Each / Each                        NaN
#
#   Products.multiple  Products.length  Products.width  Products.height  \
# 0              1 EA              NaN             NaN              NaN
# 1              1 EA              NaN             NaN              NaN
# 2              1 CS              NaN             NaN              NaN
# 3              1 EA              NaN             NaN              NaN
# 4              1 EA              NaN             NaN              NaN
#
#   Products.rx Products.latex  Products.upc Products.msds_link  \
# 0         NaN            NaN           NaN                NaN
# 1          Rx            Yes           NaN                NaN
# 2         NaN            NaN           NaN                NaN
# 3         NaN            Yes  8.019675e+10                NaN
# 4          Rx            NaN           NaN                NaN
#
#   Products.msds_label                                  Products.lit_link  \
# 0                 NaN                                                NaN
# 1                 NaN  https://medline360.medline.com:443/irj/servlet...
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#                      Products.lit_label  \
# 0                                   NaN
# 1  508f2d75-582e-2e10-2eab-d83980a9b1d0
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                       Products.hcpcs  Products.case_qty  \
# 0                                       E0149 +E0156                1.0
# 1                                              A4357                1.0
# 2  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION              800.0
# 3                                              A9270                1.0
# 4                                              E0730                1.0
#
#    Products.markup  Products.override_markup                   Products.notes  \
# 0              NaN                       0.0                              NaN
# 1              NaN                       0.0  OFF sale cause it is an RX item
# 2              NaN                       0.0                              NaN
# 3              NaN                       0.0                              NaN
# 4              NaN                       0.0  OFF sale cause it is an RX item
#
#    Products.import_flags  Products.map_price Products.features_title  \
# 0                  136.0                 NaN                     NaN
# 1                    0.0                 NaN                     NaN
# 2                    NaN                 NaN                     NaN
# 3                    NaN                 NaN                     NaN
# 4                    NaN                 NaN                     NaN
#
#   Products.warranty  Products.hygienic  Products.default_quantity  \
# 0               NaN                0.0                        NaN
# 1               NaN                0.0                        NaN
# 2               NaN                NaN                        NaN
# 3               NaN                NaN                        NaN
# 4               NaN                NaN                        NaN
#
#   Products.user_size Products.assembly Products.installation  \
# 0                NaN               NaN                   NaN
# 1                NaN               NaN                   NaN
# 2                NaN               NaN                   NaN
# 3                NaN               NaN                   NaN
# 4                NaN               NaN                   NaN
#
#    Products.shipping_length  Products.shipping_width  \
# 0                     24.80                     7.50
# 1                      8.00                     7.00
# 2                     13.23                    10.04
# 3                     10.60                     7.80
# 4                      8.50                     2.75
#
#    Products.shipping_height  Products.shipping_weight Products.handling_time  \
# 0                     30.40                       NaN                    NaN
# 1                      1.50                       NaN                    NaN
# 2                     10.24                       NaN                    NaN
# 3                     18.50                       NaN                    NaN
# 4                     12.00                       NaN                    NaN
#
#   Products.rotation_link  Products.google_shopping_label  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
#
#   Products.product_option    Products.size Products.material  \
# 0                     NaN              NaN               NaN
# 1                     NaN              NaN               NaN
# 2                     NaN  2 x Extra large           Nitrile
# 3                     NaN              NaN               NaN
# 4                     NaN              NaN               NaN
#
#   Products.arm_style  Products.leg_style Products.seat_size  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#   Products.family_id  Products.saved_status  Products.freight_cost
# 0            PF61071                    0.0                    NaN
# 1            PF02132                    NaN                    NaN
# 2            PF00342                    0.0                    NaN
# 3            PF04970                    NaN                    NaN
# 4            PF03045                    NaN                    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4194 entries, 0 to 4193
# Columns: 181 entries, Customers.id to Products.freight_cost
# dtypes: float64(98), int64(10), object(73)
# memory usage: 5.8+ MB

# %%
# Tüm satırları boş olan sütunları silelim
miss = pd.DataFrame(df.isnull().sum(), index=None)
alanlar=miss[miss[0]!=4194].index
df=df[alanlar]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4194 entries, 0 to 4193
# Columns: 147 entries, Customers.id to Products.saved_status
# dtypes: float64(64), int64(10), object(73)
# memory usage: 4.7+ MB

# %%
# Tarih alanlarını dönüştürelim.

import datetime as dt
today = dt.datetime(2024,1,1)
print(today)
# Out:
# 2024-01-01 00:00:00

# %%
t=[col for col in df.columns if 'date' in col]
t
# Out:
# ['Customers.create_date',
#  'Orders.payment_date',
#  'Orders.placed_date',
#  'Orders.updated_date',
#  'Orders.shipped_date']

# %%
for col in t:
    df[col] = pd.to_datetime(df[col], unit='s')

# %%
df.head()
# Out:
#    Customers.id Customers.fname Customers.lname Customers.company  \
# 0           797         Christy            Dill          Company0
# 1             3            John           Smith          Company1
# 2             3            John           Smith          Company1
# 3             4           James        Anderson               NaN
# 4             5         Abraham          Pollak          Company3
#
#   Customers.create_date  Customers.status  Customers.mailing  \
# 0   2015-03-10 20:18:44               NaN                NaN
# 1   2013-12-03 16:45:39               NaN                NaN
# 2   2013-12-03 16:45:39               NaN                NaN
# 3   2013-12-11 16:44:23               NaN                NaN
# 4   2013-12-12 15:19:59               0.0                0.0
#
#    Customers.tax_exempt  Customers.account_id  Customers.last_modified  \
# 0                   NaN                   NaN               1437764306
# 1                   NaN                   NaN               1437764354
# 2                   NaN                   NaN               1437764354
# 3                   NaN                   NaN               1437762646
# 4                   NaN                   NaN               1437764316
#
#    Customers.customer_type  Orders.id  Orders.customer_id Orders.fname  \
# 0                      0.0       3758                 797      Christy
# 1                      0.0         23                   3         John
# 2                      0.0       9531                   3         John
# 3                      0.0         29                   4        James
# 4                      0.0         30                   5      Abraham
#
#   Orders.lname Orders.company Orders.order_number  Orders.reorder_id  \
# 0         Dill       Company0                3758                NaN
# 1        Smith       Company1                  23                NaN
# 2        Smith       Company1                9531                NaN
# 3     Anderson            NaN                  29                NaN
# 4       Pollak       Company3                  30                NaN
#
#   Orders.external_source  Orders.external_id Orders.currency  Orders.subtotal  \
# 0                    NaN                 NaN             USD            57.20
# 1                    NaN                 NaN             USD            20.00
# 2                    NaN                 NaN             USD            68.78
# 3                   Ebay                 NaN             USD            19.56
# 4                    NaN                 NaN             USD            36.05
#
#    Orders.tax  Orders.shipping  Orders.coupon_id  Orders.coupon_amount  \
# 0         0.0             9.95              13.0                  2.86
# 1         NaN             9.99               NaN                   NaN
# 2         0.0             9.95               NaN                   NaN
# 3         0.0             9.95               NaN                   NaN
# 4         NaN             9.95               NaN                   NaN
#
#   Orders.fee_name  Orders.fee_amount Orders.discount_name  \
# 0             NaN                NaN                  NaN
# 1             NaN                NaN                  NaN
# 2             NaN                NaN                  NaN
# 3             NaN               0.04                  NaN
# 4             NaN                NaN                  NaN
#
#    Orders.discount_amount  Orders.total  Orders.balance_due  \
# 0                     NaN         64.29                 NaN
# 1                     NaN         29.99                 NaN
# 2                     NaN         78.73                 NaN
# 3                     NaN         29.55                 NaN
# 4                     NaN         46.00                 NaN
#
#   Orders.shipping_carrier Orders.shipping_method  Orders.weight  \
# 0                   fedex              11|Ground            NaN
# 1                   fedex              11|Ground            NaN
# 2                  manual    0|Standard Shipping            NaN
# 3                     NaN              11|Ground            NaN
# 4                   fedex              11|Ground            NaN
#
#   Orders.tracking  Orders.payment_status Orders.payment_date  \
# 0      5.7204E+14                    3.0 2015-03-10 20:24:59
# 1     1.28597E+14                    3.0 2013-12-03 17:07:35
# 2             NaN                    3.0 2015-12-08 19:40:52
# 3     7.96468E+14                    3.0 2013-12-11 16:44:23
# 4     6.87398E+14                    3.0 2013-12-12 15:19:59
#
#   Orders.payment_user Orders.payment_type Orders.payment_method  \
# 0                 NaN       authorize.net                   NaN
# 1                 NaN       authorize.net                   NaN
# 2           genlee166       authorize.net                   NaN
# 3                 NaN                 NaN           Credit Card
# 4                 NaN                 NaN           Credit Card
#
#    Orders.payment_amount Orders.payment_id Orders.payment_code  Orders.status  \
# 0                  64.29        6993607863              510142              1
# 1                  29.99                 0                   0              1
# 2                  78.73                 0                   0              3
# 3                  29.55               NaN                 NaN              1
# 4                  46.00               NaN                 NaN              1
#
#    Orders.placed_date Orders.updated_date Orders.shipped_date  \
# 0 2015-03-10 20:24:59 2015-08-06 13:40:10 2015-03-11 19:08:42
# 1 2013-12-03 17:07:35 2015-08-25 18:49:43 2013-12-03 20:30:21
# 2 2015-12-08 19:40:52 2015-12-15 21:04:47                 NaT
# 3 2013-12-11 16:44:23 2015-08-25 18:49:43 2013-12-11 22:15:32
# 4 2013-12-12 15:19:59 2015-08-25 18:49:43 2013-12-12 19:13:43
#
#                Orders.comments          Orders.notes  Orders.flags  \
# 0                          NaN  Insured By Eye4Fraud           NaN
# 1                          NaN                   NaN           NaN
# 2                   test order                  Test           NaN
# 3  ebay order\rpaid by pay pal                   NaN           NaN
# 4                          NaN                   NaN           NaN
#
#    Orders.partial_ship  Orders.customer_type  Order_Items.id  \
# 0                  NaN                   0.0            5284
# 1                  NaN                   0.0              31
# 2                  NaN                   0.0           11655
# 3                  NaN                   0.0            1816
# 4                  NaN                   0.0              40
#
#    Order_Items.parent  Order_Items.product_id  \
# 0                3758                  2310.0
# 1                  23                   177.0
# 2                9531                     1.0
# 3                  29                   983.0
# 4                  30                   991.0
#
#                         Order_Items.product_name Order_Items.attribute_names  \
# 0                         Basic Rollators, Green                         NaN
# 1                       Urinary Drain Bags,0.000                         NaN
# 2  SensiCare Nitrile Exam Gloves, Blue, XX-Large                         NaN
# 3                    Basket for 2-Button Walkers                         NaN
# 4                                     Tens Units                         NaN
#
#    Order_Items.qty  Order_Items.price  Order_Items.cost  \
# 0                1              57.20             44.00
# 1                4               5.00              1.87
# 2                1              68.78             52.50
# 3                1              19.56             12.62
# 4                1              36.05             25.75
#
#    Order_Items.reorder_frequency  Order_Items.flags  Products.id  \
# 0                            NaN                NaN       2310.0
# 1                            NaN                2.0        177.0
# 2                            NaN                NaN          1.0
# 3                            NaN                NaN        983.0
# 4                            NaN                NaN        991.0
#
#    Products.status        Products.template  Products.vendor  \
# 0              0.0  sub-product-detail.html              1.0
# 1              1.0  sub-product-detail.html              1.0
# 2              0.0  sub-product-detail.html              1.0
# 3              0.0  sub-product-detail.html              1.0
# 4              1.0  sub-product-detail.html              1.0
#
#    Products.import_id                                Products.name  \
# 0                 3.0                  Basic Steel Rollators,Green
# 1                 3.0                           Urinary Drain Bags
# 2                 3.0  SensiCare Nitrile Exam Gloves,Blue,XX-Large
# 3                 3.0                  Basket for 2-Button Walkers
# 4                 3.0                        TENS 3000 Analog Unit
#
#                                Products.display_name  Products.list_price  \
# 0  Basic Lightweight Rollators For Adults, With S...                80.70
# 1                                 Urinary Drain Bags                14.41
# 2      SensiCare Nitrile Exam Gloves, Blue, XX-Large                96.29
# 3                        Basket for 2-Button Walkers                27.38
# 4                              TENS 3000 Analog Unit                50.47
#
#    Products.price  Products.sale_price  Products.cost  Products.flags  \
# 0           57.64                  NaN          44.00             0.0
# 1           10.29                  5.0           1.87            65.0
# 2           68.78                  NaN          52.50         32896.0
# 3           19.56                  NaN          12.62             0.0
# 4           36.05                  NaN          25.75             0.0
#
#    Products.left_flag  Products.last_modified  Products.taxable  \
# 0                 NaN            1.463163e+09               1.0
# 1                 NaN            1.462370e+09               1.0
# 2                 NaN            1.463163e+09               1.0
# 3                 NaN            1.462595e+09               1.0
# 4                 NaN            1.462370e+09               1.0
#
#    Products.shopping_gtin Products.shopping_brand Products.shopping_mpn  \
# 0            1.088440e+13                 MEDLINE           MDS86850EGS
# 1            1.008020e+13                 MEDLINE             DYNC1674H
# 2            4.008020e+13                 MEDLINE                484805
# 3                     NaN                 MEDLINE            MDS86615KH
# 4                     NaN      ROSCOE MEDICAL INC              MDS86710
#
#   Products.shopping_gender Products.shopping_color Products.shopping_age  \
# 0                      NaN                   Green                   NaN
# 1                      NaN                     NaN                   NaN
# 2                      NaN                    Blue                   NaN
# 3                      NaN                     NaN                   NaN
# 4                      NaN                     NaN                   NaN
#
#    Products.shopping_flags Products.amazon_asin Products.amazon_item_type  \
# 0                     62.0           B00I6GQE0A      health-care-products
# 1                     62.0           B000QF7Y76      health-care-products
# 2                     62.0           B002209AOI      health-care-products
# 3                     62.0           B00083DG00      health-care-products
# 4                     62.0                  NaN      health-care-products
#
#    Products.amazon_price      Products.google_shopping_id  \
# 0                    NaN  generic/online%3Aen%3AUS%3A2310
# 1                    NaN                              NaN
# 2                    NaN     generic/online%3Aen%3AUS%3A1
# 3                    NaN                              NaN
# 4                    NaN                              NaN
#
#                        Products.google_shopping_type  \
# 0    Walking Aids > Rollators, & Walkers > Rollators
# 1  Incontinence, Urology & Ostomy > Urology > Dra...
# 2  Apparel > Gloves > Nonsterile PF LF Synthetic ...
# 3  Walking Aids > Rollators, & Walkers > Walkers ...
# 4   Physical Therapy > Electronic Muscle Stimulation
#
#     Products.google_shopping_cat  Products.shopping_cat  \
# 0  Health & Beauty > Health Care                    NaN
# 1  Health & Beauty > Health Care                  199.0
# 2  Health & Beauty > Health Care                  199.0
# 3  Health & Beauty > Health Care                  199.0
# 4  Health & Beauty > Health Care                  199.0
#
#   Products.shopping_type                          Products.pricegrabber_cat  \
# 0                    NaN                                                NaN
# 1          Miscellaneous  Health & Beauty > Medical Supplies > Medical Aids
# 2          Miscellaneous  Health & Beauty > Medical Supplies > Medical Aids
# 3          Miscellaneous  Health & Beauty > Medical Supplies > Medical Aids
# 4          Miscellaneous  Health & Beauty > Medical Supplies > Medical Aids
#
#    Products.shopzilla_cat                               Products.thefind_cat  \
# 0                     NaN                                                NaN
# 1                 22005.0  Health & Beauty > Medical Supplies > Medical Aids
# 2                 22005.0  Health & Beauty > Medical Supplies > Medical Aids
# 3                 22005.0  Health & Beauty > Medical Supplies > Medical Aids
# 4                 22005.0  Health & Beauty > Medical Supplies > Medical Aids
#
#   Products.quickbooks_id  Products.qb_edit_sequence  \
# 0    8000064C-1434298761               1.450325e+09
# 1    80008C35-1438901283               1.450322e+09
# 2    800087BB-1438898332               1.450321e+09
# 3    8000065E-1434298780               1.450323e+09
# 4    80008B12-1438900627               1.450323e+09
#
#                  Products.short_description  \
# 0             ROLLATOR,BASIC,STEEL,6",GREEN
# 1   BAG,DRAINAGE,UROLOGY,2000ML,ANTI REFLUX
# 2  GLOVE,EXAM,NITRILE,BLUE,FINGRTIP,TXT,XXL
# 3           BASKET,WALKER,FOR 2 BUTTON WALK
# 4        DEVICE,TENS UNIT,TENS 1000,DUAL CH
#
#                            Products.long_description Products.video  \
# 0  <ul><li>  Classically designed, value priced</...            NaN
# 1  <ul><li>  Only Medline drain bags have a slide...            NaN
# 2  <ul><li> SensiCare&reg; nitrile exam gloves fe...            NaN
# 3  <ul><li> This wire basket attaches to almost a...            NaN
# 4  <ul><li> The TENS 3000<sup>TM</sup> analog uni...            NaN
#
#                                   Products.seo_title Products.seo_description  \
# 0  Basic Lightweight Rollators For Adults, With S...                      NaN
# 1           Urinary Drain Bags | MEDLINE - DYNC1674H                      NaN
# 2  Nitrile Exam Gloves, Blue, XX-Large | MEDLINE ...                      NaN
# 3  Basket for 2-Button Walkers | MEDLINE - MDS866...                      NaN
# 4  TENS 3000 Analog Unit | ROSCOE MEDICAL INC - M...                      NaN
#
#   Products.seo_keywords Products.seo_header  \
# 0                   NaN                 NaN
# 1                   NaN                 NaN
# 2                   NaN                 NaN
# 3                   NaN                 NaN
# 4                   NaN                 NaN
#
#                                     Products.seo_url  Products.seo_category  \
# 0  Basic-Rollators-For-Adults-With-Seat-Green-6-W...                    0.0
# 1                             Urinary-Drain-Bags0000                    0.0
# 2          SensiCare-Nitrile-Exam-GlovesBlueXX-Large                    0.0
# 3                      Basket-for-2-Button-Walkers-2                    0.0
# 4                                         Tens-Units                    0.0
#
#   Products.unit Products.packaging Products.display_packaging  \
# 0            EA      1 Each / Each                        NaN
# 1            EA      1 Each / Each                        NaN
# 2            CS    800 Each / Case                        NaN
# 3            EA      1 Each / Each                        NaN
# 4            EA      1 Each / Each                        NaN
#
#   Products.multiple  Products.length  Products.width  Products.height  \
# 0              1 EA              NaN             NaN              NaN
# 1              1 EA              NaN             NaN              NaN
# 2              1 CS              NaN             NaN              NaN
# 3              1 EA              NaN             NaN              NaN
# 4              1 EA              NaN             NaN              NaN
#
#   Products.rx Products.latex  Products.upc Products.msds_link  \
# 0         NaN            NaN           NaN                NaN
# 1          Rx            Yes           NaN                NaN
# 2         NaN            NaN           NaN                NaN
# 3         NaN            Yes  8.019675e+10                NaN
# 4          Rx            NaN           NaN                NaN
#
#   Products.msds_label                                  Products.lit_link  \
# 0                 NaN                                                NaN
# 1                 NaN  https://medline360.medline.com:443/irj/servlet...
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#                      Products.lit_label  \
# 0                                   NaN
# 1  508f2d75-582e-2e10-2eab-d83980a9b1d0
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                       Products.hcpcs  Products.case_qty  \
# 0                                       E0149 +E0156                1.0
# 1                                              A4357                1.0
# 2  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION              800.0
# 3                                              A9270                1.0
# 4                                              E0730                1.0
#
#    Products.override_markup                   Products.notes  \
# 0                       0.0                              NaN
# 1                       0.0  OFF sale cause it is an RX item
# 2                       0.0                              NaN
# 3                       0.0                              NaN
# 4                       0.0  OFF sale cause it is an RX item
#
#    Products.import_flags  Products.map_price Products.features_title  \
# 0                  136.0                 NaN                     NaN
# 1                    0.0                 NaN                     NaN
# 2                    NaN                 NaN                     NaN
# 3                    NaN                 NaN                     NaN
# 4                    NaN                 NaN                     NaN
#
#   Products.warranty  Products.hygienic Products.user_size Products.assembly  \
# 0               NaN                0.0                NaN               NaN
# 1               NaN                0.0                NaN               NaN
# 2               NaN                NaN                NaN               NaN
# 3               NaN                NaN                NaN               NaN
# 4               NaN                NaN                NaN               NaN
#
#   Products.installation  Products.shipping_length  Products.shipping_width  \
# 0                   NaN                     24.80                     7.50
# 1                   NaN                      8.00                     7.00
# 2                   NaN                     13.23                    10.04
# 3                   NaN                     10.60                     7.80
# 4                   NaN                      8.50                     2.75
#
#    Products.shipping_height  Products.shipping_weight Products.handling_time  \
# 0                     30.40                       NaN                    NaN
# 1                      1.50                       NaN                    NaN
# 2                     10.24                       NaN                    NaN
# 3                     18.50                       NaN                    NaN
# 4                     12.00                       NaN                    NaN
#
#   Products.rotation_link  Products.google_shopping_label  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
#
#   Products.product_option    Products.size Products.material  \
# 0                     NaN              NaN               NaN
# 1                     NaN              NaN               NaN
# 2                     NaN  2 x Extra large           Nitrile
# 3                     NaN              NaN               NaN
# 4                     NaN              NaN               NaN
#
#   Products.arm_style Products.seat_size Products.family_id  \
# 0                NaN                NaN            PF61071
# 1                NaN                NaN            PF02132
# 2                NaN                NaN            PF00342
# 3                NaN                NaN            PF04970
# 4                NaN                NaN            PF03045
#
#    Products.saved_status
# 0                    0.0
# 1                    NaN
# 2                    0.0
# 3                    NaN
# 4                    NaN

# %%
# Tabloları ayıralım

c = [col for col in df.columns if 'Customers.' in col]
o = [col for col in df.columns if 'Orders.' in col]
oi = [col for col in df.columns if 'Order_Items.' in col]
p = [col for col in df.columns if 'Products.' in col]
c,o,oi,p
# Out:
# (['Customers.id',
#   'Customers.fname',
#   'Customers.lname',
#   'Customers.company',
#   'Customers.create_date',
#   'Customers.status',
#   'Customers.mailing',
#   'Customers.tax_exempt',
#   'Customers.account_id',
#   'Customers.last_modified',
#   'Customers.customer_type'],
#  ['Orders.id',
#   'Orders.customer_id',
#   'Orders.fname',
#   'Orders.lname',
#   'Orders.company',
#   'Orders.order_number',
#   'Orders.reorder_id',
#   'Orders.external_source',
#   'Orders.external_id',
#   'Orders.currency',
#   'Orders.subtotal',
#   'Orders.tax',
#   'Orders.shipping',
#   'Orders.coupon_id',
#   'Orders.coupon_amount',
#   'Orders.fee_name',
#   'Orders.fee_amount',
#   'Orders.discount_name',
#   'Orders.discount_amount',
#   'Orders.total',
#   'Orders.balance_due',
#   'Orders.shipping_carrier',
#   'Orders.shipping_method',
#   'Orders.weight',
#   'Orders.tracking',
#   'Orders.payment_status',
#   'Orders.payment_date',
#   'Orders.payment_user',
#   'Orders.payment_type',
#   'Orders.payment_method',
#   'Orders.payment_amount',
#   'Orders.payment_id',
#   'Orders.payment_code',
#   'Orders.status',
#   'Orders.placed_date',
#   'Orders.updated_date',
#   'Orders.shipped_date',
#   'Orders.comments',
#   'Orders.notes',
#   'Orders.flags',
#   'Orders.partial_ship',
#   'Orders.customer_type'],
#  ['Order_Items.id',
#   'Order_Items.parent',
#   'Order_Items.product_id',
#   'Order_Items.product_name',
#   'Order_Items.attribute_names',
#   'Order_Items.qty',
#   'Order_Items.price',
#   'Order_Items.cost',
#   'Order_Items.reorder_frequency',
#   'Order_Items.flags'],
#  ['Products.id',
#   'Products.status',
#   'Products.template',
#   'Products.vendor',
#   'Products.import_id',
#   'Products.name',
#   'Products.display_name',
#   'Products.list_price',
#   'Products.price',
#   'Products.sale_price',
#   'Products.cost',
#   'Products.flags',
#   'Products.left_flag',
#   'Products.last_modified',
#   'Products.taxable',
#   'Products.shopping_gtin',
#   'Products.shopping_brand',
#   'Products.shopping_mpn',
#   'Products.shopping_gender',
#   'Products.shopping_color',
#   'Products.shopping_age',
#   'Products.shopping_flags',
#   'Products.amazon_asin',
#   'Products.amazon_item_type',
#   'Products.amazon_price',
#   'Products.google_shopping_id',
#   'Products.google_shopping_type',
#   'Products.google_shopping_cat',
#   'Products.shopping_cat',
#   'Products.shopping_type',
#   'Products.pricegrabber_cat',
#   'Products.shopzilla_cat',
#   'Products.thefind_cat',
#   'Products.quickbooks_id',
#   'Products.qb_edit_sequence',
#   'Products.short_description',
#   'Products.long_description',
#   'Products.video',
#   'Products.seo_title',
#   'Products.seo_description',
#   'Products.seo_keywords',
#   'Products.seo_header',
#   'Products.seo_url',
#   'Products.seo_category',
#   'Products.unit',
#   'Products.packaging',
#   'Products.display_packaging',
#   'Products.multiple',
#   'Products.length',
#   'Products.width',
#   'Products.height',
#   'Products.rx',
#   'Products.latex',
#   'Products.upc',
#   'Products.msds_link',
#   'Products.msds_label',
#   'Products.lit_link',
#   'Products.lit_label',
#   'Products.hcpcs',
#   'Products.case_qty',
#   'Products.override_markup',
#   'Products.notes',
#   'Products.import_flags',
#   'Products.map_price',
#   'Products.features_title',
#   'Products.warranty',
#   'Products.hygienic',
#   'Products.user_size',
#   'Products.assembly',
#   'Products.installation',
#   'Products.shipping_length',
#   'Products.shipping_width',
#   'Products.shipping_height',
#   'Products.shipping_weight',
#   'Products.handling_time',
#   'Products.rotation_link',
#   'Products.google_shopping_label',
#   'Products.product_option',
#   'Products.size',
#   'Products.material',
#   'Products.arm_style',
#   'Products.seat_size',
#   'Products.family_id',
#   'Products.saved_status'])

# %%
# Her bir tablo için bir Data Frame oluşturalım

dfC=df[c]
dfO=df[o]
dfOi=df[oi]
dfP=df[p]

dfC.columns = dfC.columns.str.replace('Customers.', '')
dfO.columns = dfO.columns.str.replace('Orders.', '')
dfOi.columns = dfOi.columns.str.replace('Order_Items.', '')
dfP.columns = dfP.columns.str.replace('Products.', '')

# %%
# Tekrar kayıtlar varsa silelim

dfC=dfC.drop_duplicates(subset="id")
dfO=dfO.drop_duplicates(subset="id")
dfOi=dfOi.drop_duplicates(subset="id")
dfP=dfP.drop_duplicates(subset="id")

# %%
dfC.head()
# Out:
#     id    fname     lname   company         create_date  status  mailing  \
# 0  797  Christy      Dill  Company0 2015-03-10 20:18:44     NaN      NaN
# 1    3     John     Smith  Company1 2013-12-03 16:45:39     NaN      NaN
# 3    4    James  Anderson       NaN 2013-12-11 16:44:23     NaN      NaN
# 4    5  Abraham    Pollak  Company3 2013-12-12 15:19:59     0.0      0.0
# 7    7   peggy   thompson       NaN 2013-12-27 14:52:27     NaN      NaN
#
#    tax_exempt  account_id  last_modified  customer_type
# 0         NaN         NaN     1437764306            0.0
# 1         NaN         NaN     1437764354            0.0
# 3         NaN         NaN     1437762646            0.0
# 4         NaN         NaN     1437764316            0.0
# 7         NaN         NaN     1437763617            0.0

# %% [markdown]
# ### Veri Tabanı İşlemleri

# %%
import sqlite3
from sqlite3 import Error

# %%
conn = sqlite3.connect("customer_data.db")

# %%
dfC.to_sql('Customers', con=conn)
dfO.to_sql('Orders', con=conn)
dfOi.to_sql('OrderItems', con=conn)
dfP.to_sql('Products', con=conn)
# Out:
# -1

# %%
conn.execute("SELECT * FROM Customers").fetchall()
# Out:
# [(0,
#   797,
#   'Christy',
#   'Dill',
#   'Company0',
#   '2015-03-10 20:18:44',
#   None,
#   None,
#   None,
#   None,
#   1437764306,
#   0.0),
#  (1,
#   3,
#   'John',
#   'Smith',
#   'Company1',
#   '2013-12-03 16:45:39',
#   None,
#   None,
#   None,
#   None,
#   1437764354,
#   0.0),
#  (3,
#   4,
#   'James',
#   'Anderson',
#   None,
#   '2013-12-11 16:44:23',
#   None,
#   None,
#   None,
#   None,
#   1437762646,
#   0.0),
#  (4,
#   5,
#   'Abraham',
#   'Pollak',
#   'Company3',
#   '2013-12-12 15:19:59',
#   0.0,
#   0.0,
#   None,
#   None,
#   1437764316,
#   0.0),
#  (7,
#   7,
#   'peggy ',
#   'thompson',
#   None,
#   '2013-12-27 14:52:27',
#   None,
#   None,
#   None,
#   None,
#   1437763617,
#   0.0),
#  (8,
#   8,
#   'Randy',
#   'Pruss',
#   None,
#   '2014-01-09 21:33:36',
#   None,
#   None,
#   None,
#   None,
#   1437763421,
#   0.0),
#  (9,
#   10,
#   'Tommy ',
#   'Smith',
#   None,
#   '2014-01-23 20:38:36',
#   None,
#   None,
#   None,
#   None,
#   1437763553,
#   0.0),
#  (10,
#   11,
#   'Mark',
#   'Tremble',
#   None,
#   '2014-01-24 14:19:15',
#   None,
#   None,
#   None,
#   None,
#   1437763644,
#   0.0),
#  (11,
#   12,
#   'Emely',
#   'Cooke',
#   None,
#   '2014-01-25 01:28:34',
#   None,
#   None,
#   None,
#   None,
#   1437762807,
#   0.0),
#  (12,
#   13,
#   'george',
#   'mcmillin',
#   None,
#   '2014-01-27 20:53:59',
#   None,
#   None,
#   None,
#   None,
#   1437763265,
#   0.0),
#  (15,
#   14,
#   'adrian',
#   'Cavitt',
#   None,
#   '2014-01-29 16:13:37',
#   None,
#   None,
#   None,
#   None,
#   1437762774,
#   0.0),
#  (16,
#   15,
#   'Sharon',
#   'Mueller',
#   None,
#   '2014-02-02 17:41:13',
#   None,
#   1.0,
#   None,
#   None,
#   1437763316,
#   0.0),
#  (17,
#   66,
#   'Norrell',
#   'Nelson',
#   None,
#   '2014-03-20 20:50:41',
#   None,
#   None,
#   None,
#   None,
#   1437763333,
#   0.0),
#  (18,
#   21,
#   'Corey ',
#   'Edmondson',
#   None,
#   '2014-02-05 16:45:32',
#   None,
#   None,
#   None,
#   None,
#   1437762877,
#   0.0),
#  (19,
#   22,
#   'Robert',
#   'Miller',
#   None,
#   '2014-02-07 23:16:06',
#   None,
#   None,
#   None,
#   None,
#   1437763278,
#   0.0),
#  (20,
#   23,
#   'Mekala',
#   'Whitaker',
#   None,
#   '2014-02-08 21:59:06',
#   None,
#   None,
#   None,
#   None,
#   1437763710,
#   0.0),
#  (24,
#   24,
#   'Richard ',
#   'Ariano',
#   None,
#   '2014-02-10 16:07:54',
#   None,
#   None,
#   None,
#   None,
#   1437762652,
#   0.0),
#  (25,
#   25,
#   'marc ',
#   'gorzynski',
#   None,
#   '2014-02-10 16:10:47',
#   None,
#   None,
#   None,
#   None,
#   1437762986,
#   0.0),
#  (26,
#   26,
#   'Richard L. ',
#   'Shaak',
#   None,
#   '2014-02-10 17:38:57',
#   None,
#   None,
#   None,
#   None,
#   1437763531,
#   0.0),
#  (27,
#   27,
#   'Kenneth ',
#   'Schmude',
#   None,
#   '2014-02-11 15:46:40',
#   None,
#   None,
#   None,
#   None,
#   1437763518,
#   0.0),
#  (34,
#   65,
#   'Allette',
#   'Hannon',
#   None,
#   '2014-03-20 17:31:14',
#   None,
#   None,
#   None,
#   None,
#   1437763013,
#   0.0),
#  (37,
#   30,
#   'Jesse ',
#   'Spalding',
#   None,
#   '2014-02-13 17:17:08',
#   None,
#   None,
#   None,
#   None,
#   1437763560,
#   0.0),
#  (38,
#   31,
#   'Alan',
#   'Safir',
#   'Company4',
#   '2014-02-14 15:28:03',
#   None,
#   None,
#   None,
#   None,
#   1437764336,
#   0.0),
#  (39,
#   32,
#   'Elvia',
#   'Mejia',
#   None,
#   '2014-02-14 16:08:30',
#   None,
#   None,
#   None,
#   None,
#   1437763266,
#   0.0),
#  (40,
#   33,
#   'Sheryl',
#   'Martinez',
#   None,
#   '2014-02-15 17:22:35',
#   None,
#   None,
#   None,
#   None,
#   1437763230,
#   0.0),
#  (41,
#   35,
#   'jennifer',
#   'fletcher',
#   'Company5',
#   '2014-02-21 19:48:13',
#   None,
#   1.0,
#   None,
#   None,
#   1437764293,
#   0.0),
#  (42,
#   37,
#   'Satish',
#   'Karandikar',
#   None,
#   '2014-02-24 00:47:35',
#   None,
#   None,
#   None,
#   None,
#   1437763100,
#   0.0),
#  (43,
#   39,
#   'James',
#   'Head',
#   None,
#   '2014-02-25 23:13:23',
#   None,
#   None,
#   None,
#   None,
#   1437763022,
#   0.0),
#  (44,
#   40,
#   'Leonard',
#   'Sachs',
#   None,
#   '2014-02-27 18:01:13',
#   None,
#   None,
#   None,
#   None,
#   1437763489,
#   0.0),
#  (45,
#   41,
#   'troy',
#   'winder',
#   None,
#   '2014-02-27 20:47:26',
#   None,
#   None,
#   None,
#   None,
#   1437764242,
#   0.0),
#  (47,
#   42,
#   'Tiffany',
#   'Hooper',
#   None,
#   '2014-03-01 13:35:49',
#   None,
#   1.0,
#   None,
#   None,
#   1437763057,
#   0.0),
#  (48,
#   43,
#   'Carla',
#   'Torres',
#   None,
#   '2014-03-01 22:08:02',
#   None,
#   None,
#   None,
#   None,
#   1437763628,
#   0.0),
#  (49,
#   44,
#   'Erika',
#   'Dorado',
#   None,
#   '2014-03-03 16:00:28',
#   None,
#   None,
#   None,
#   None,
#   1437762859,
#   0.0),
#  (50,
#   45,
#   'rafael',
#   'chemtob',
#   'Company6',
#   '2014-03-04 20:59:02',
#   None,
#   1.0,
#   None,
#   None,
#   1437764308,
#   0.0),
#  (60,
#   46,
#   'Carol',
#   'Carol',
#   None,
#   '2014-03-04 21:54:30',
#   None,
#   None,
#   None,
#   None,
#   1437762763,
#   0.0),
#  (61,
#   48,
#   'Blu',
#   'Morris',
#   'Company7',
#   '2014-03-06 01:08:57',
#   None,
#   1.0,
#   None,
#   None,
#   1437764419,
#   0.0),
#  (62,
#   50,
#   'Rob',
#   'Inie',
#   None,
#   '2014-03-06 22:43:57',
#   None,
#   None,
#   None,
#   None,
#   1437763078,
#   0.0),
#  (63,
#   52,
#   'Kenneth',
#   'Long',
#   'Company8',
#   '2014-03-08 01:46:02',
#   None,
#   None,
#   None,
#   None,
#   1437763189,
#   0.0),
#  (64,
#   55,
#   'patricia',
#   'davenport3429 us',
#   None,
#   '2014-03-10 05:56:02',
#   None,
#   None,
#   None,
#   None,
#   1437559494,
#   0.0),
#  (71,
#   56,
#   'Mark',
#   'Fortune',
#   'Company9',
#   '2014-03-11 00:02:03',
#   None,
#   None,
#   None,
#   None,
#   1437764371,
#   0.0),
#  (72,
#   57,
#   'Robert',
#   'Leonard',
#   None,
#   '2014-03-13 13:17:29',
#   None,
#   None,
#   None,
#   None,
#   1437763168,
#   0.0),
#  (73,
#   59,
#   'Bobby',
#   'Bennett',
#   'Company10',
#   '2014-03-14 21:29:21',
#   None,
#   None,
#   None,
#   None,
#   1437764387,
#   0.0),
#  (74,
#   60,
#   'Monette',
#   'Molinar',
#   None,
#   '2014-03-14 22:29:47',
#   None,
#   None,
#   None,
#   None,
#   1437763286,
#   0.0),
#  (75,
#   61,
#   'james',
#   'huff',
#   None,
#   '2014-03-17 12:26:07',
#   None,
#   None,
#   None,
#   None,
#   1437763061,
#   0.0),
#  (76,
#   62,
#   'Steven',
#   'Galagarza',
#   None,
#   '2014-03-17 18:10:11',
#   None,
#   None,
#   None,
#   None,
#   1437762946,
#   0.0),
#  (77,
#   63,
#   'Jannett ',
#   'Stewart',
#   None,
#   '2014-03-18 21:42:19',
#   None,
#   1.0,
#   None,
#   None,
#   1437763571,
#   0.0),
#  (78,
#   68,
#   'barry',
#   'siegel',
#   None,
#   '2014-03-21 15:08:20',
#   None,
#   None,
#   None,
#   None,
#   1437763540,
#   0.0),
#  (79,
#   69,
#   'Jill',
#   'Shulman',
#   None,
#   '2014-03-21 16:13:05',
#   None,
#   None,
#   None,
#   None,
#   1437763539,
#   0.0),
#  (80,
#   70,
#   'Michelle',
#   'Petrelli',
#   None,
#   '2014-03-21 16:28:23',
#   None,
#   None,
#   None,
#   None,
#   1437763392,
#   0.0),
#  (81,
#   71,
#   'Ana Maria',
#   'Puente',
#   None,
#   '2014-03-22 01:38:36',
#   None,
#   None,
#   None,
#   None,
#   1437763423,
#   0.0),
#  (82,
#   72,
#   'Jean ',
#   'Conary',
#   None,
#   '2014-03-23 15:08:57',
#   None,
#   None,
#   None,
#   None,
#   1437762803,
#   0.0),
#  (83,
#   73,
#   'michael',
#   'hughes',
#   None,
#   '2014-03-23 21:02:49',
#   None,
#   1.0,
#   None,
#   None,
#   1437763064,
#   0.0),
#  (86,
#   74,
#   'Richard',
#   'Ernst',
#   'Company11',
#   '2014-03-24 19:37:11',
#   None,
#   None,
#   None,
#   None,
#   1437764445,
#   0.0),
#  (87,
#   75,
#   'Scott',
#   'Meyer',
#   None,
#   '2014-03-25 05:49:53',
#   None,
#   None,
#   None,
#   None,
#   1437763274,
#   0.0),
#  (88,
#   76,
#   'Iddo',
#   'Enochs',
#   None,
#   '2014-03-25 16:07:19',
#   None,
#   None,
#   None,
#   None,
#   1437762888,
#   0.0),
#  (89,
#   77,
#   'william',
#   'payne',
#   'Company12',
#   '2014-03-25 22:18:59',
#   None,
#   None,
#   None,
#   None,
#   1437764442,
#   0.0),
#  (90,
#   78,
#   'Sheila',
#   'Collier',
#   'Company13',
#   '2014-03-26 17:37:25',
#   None,
#   None,
#   None,
#   None,
#   1437764312,
#   0.0),
#  (91,
#   79,
#   'Karen',
#   'Sims',
#   None,
#   '2014-03-27 21:39:34',
#   None,
#   None,
#   None,
#   None,
#   1437560448,
#   0.0),
#  (96,
#   82,
#   'NIck',
#   'Kresovich',
#   None,
#   '2014-03-28 16:59:37',
#   None,
#   None,
#   None,
#   None,
#   1437763132,
#   0.0),
#  (97,
#   84,
#   'Robin',
#   'Fryzel',
#   None,
#   '2014-03-31 20:11:54',
#   None,
#   None,
#   None,
#   None,
#   1437762939,
#   0.0),
#  (98,
#   85,
#   'vera',
#   'arborio',
#   None,
#   '2014-04-02 12:06:49',
#   None,
#   None,
#   None,
#   None,
#   1437762651,
#   0.0),
#  (101,
#   100,
#   'Arlene ',
#   'Maldonado',
#   None,
#   '2014-04-02 21:09:53',
#   None,
#   None,
#   None,
#   None,
#   1437763206,
#   0.0),
#  (104,
#   101,
#   'Mark',
#   'Forte',
#   None,
#   '2014-04-02 21:35:54',
#   None,
#   None,
#   None,
#   None,
#   1437762929,
#   0.0),
#  (106,
#   102,
#   'Maria',
#   'Villatoro',
#   None,
#   '2014-04-03 00:51:54',
#   None,
#   1.0,
#   None,
#   None,
#   1437763673,
#   0.0),
#  (107,
#   103,
#   'Nurilla',
#   'Abdullayev',
#   None,
#   '2014-04-03 17:54:41',
#   0.0,
#   0.0,
#   None,
#   None,
#   1437762616,
#   0.0),
#  (108,
#   104,
#   'Roslyn',
#   'Silvernagel',
#   None,
#   '2014-04-04 03:57:50',
#   None,
#   None,
#   None,
#   None,
#   1437763541,
#   0.0),
#  (113,
#   105,
#   'Ryan',
#   'Oler',
#   None,
#   '2014-04-04 04:36:09',
#   None,
#   None,
#   None,
#   None,
#   1437763353,
#   0.0),
#  (114,
#   106,
#   'Mike ',
#   'Tidwell',
#   'Company14',
#   '2014-04-05 21:26:17',
#   None,
#   None,
#   None,
#   None,
#   1437764277,
#   0.0),
#  (115,
#   217,
#   'Andrew ',
#   'Chapman',
#   None,
#   '2014-07-01 19:23:22',
#   None,
#   None,
#   None,
#   None,
#   1437762781,
#   0.0),
#  (116,
#   112,
#   'Barry',
#   'Oxford',
#   None,
#   '2014-04-13 19:49:29',
#   None,
#   None,
#   None,
#   None,
#   1437763363,
#   0.0),
#  (117,
#   113,
#   'SPECIAL ORDER',
#   'S JOSE',
#   'Company15',
#   '2014-04-16 21:32:05',
#   None,
#   None,
#   None,
#   None,
#   1437764358,
#   0.0),
#  (118,
#   114,
#   'Eddy',
#   'Gee',
#   None,
#   '2014-04-20 16:31:43',
#   None,
#   None,
#   None,
#   None,
#   1437762964,
#   0.0),
#  (119,
#   115,
#   'Kimie',
#   'Ohori',
#   None,
#   '2014-04-24 16:38:33',
#   None,
#   None,
#   None,
#   None,
#   1437763350,
#   0.0),
#  (120,
#   116,
#   'Anna',
#   'Rothenhausler',
#   None,
#   '2014-04-28 13:53:42',
#   None,
#   None,
#   None,
#   None,
#   1437763478,
#   0.0),
#  (121,
#   117,
#   'amaury ',
#   'ORTIZ',
#   None,
#   '2014-04-29 13:42:53',
#   None,
#   None,
#   None,
#   None,
#   1437763359,
#   0.0),
#  (122,
#   118,
#   'michelle',
#   'suarez',
#   None,
#   '2014-04-29 13:46:19',
#   None,
#   None,
#   None,
#   None,
#   1437763591,
#   0.0),
#  (123,
#   120,
#   'Dwight ',
#   'Smith',
#   None,
#   '2014-05-02 13:44:53',
#   None,
#   None,
#   None,
#   None,
#   1437763551,
#   0.0),
#  (124,
#   121,
#   'Tomorra ',
#   'Valdez',
#   None,
#   '2014-05-02 13:48:03',
#   None,
#   None,
#   None,
#   None,
#   1437763658,
#   0.0),
#  (125,
#   122,
#   'Jessie',
#   'Whitus',
#   None,
#   '2014-05-05 00:54:38',
#   None,
#   None,
#   None,
#   None,
#   1437764217,
#   0.0),
#  (126,
#   123,
#   'Thomas',
#   'Jordan',
#   None,
#   '2014-05-05 17:23:11',
#   None,
#   None,
#   None,
#   None,
#   1437763098,
#   0.0),
#  (127,
#   124,
#   'Terry',
#   'Schneider',
#   'Company16',
#   '2014-05-05 19:59:51',
#   None,
#   None,
#   None,
#   None,
#   1437764346,
#   0.0),
#  (128,
#   125,
#   'mark ',
#   'marchand',
#   None,
#   '2014-05-07 14:59:18',
#   None,
#   None,
#   None,
#   None,
#   1437763218,
#   0.0),
#  (129,
#   128,
#   'Patricia',
#   'Powell',
#   None,
#   '2014-05-11 16:17:02',
#   None,
#   None,
#   None,
#   None,
#   1437763415,
#   0.0),
#  (130,
#   129,
#   'Paul',
#   'Wong',
#   None,
#   '2014-05-11 16:19:38',
#   None,
#   None,
#   None,
#   None,
#   1437764253,
#   0.0),
#  (131,
#   130,
#   'phil ',
#   'coover',
#   None,
#   '2014-05-12 13:17:14',
#   None,
#   None,
#   None,
#   None,
#   1437762813,
#   0.0),
#  (132,
#   131,
#   'Claudia ',
#   'Vital',
#   None,
#   '2014-05-12 13:20:18',
#   None,
#   None,
#   None,
#   None,
#   1437763674,
#   0.0),
#  (133,
#   132,
#   'Chao ',
#   'Chen',
#   None,
#   '2014-05-12 16:16:27',
#   None,
#   None,
#   None,
#   None,
#   1437762788,
#   0.0),
#  (134,
#   133,
#   'Aaron ',
#   'Taylor',
#   None,
#   '2014-05-12 20:33:58',
#   None,
#   None,
#   None,
#   None,
#   1437763606,
#   0.0),
#  (135,
#   134,
#   'Virginia',
#   'Lopez',
#   None,
#   '2014-05-12 21:18:31',
#   None,
#   None,
#   None,
#   None,
#   1437763190,
#   0.0),
#  (136,
#   135,
#   'Harry',
#   'Stokes',
#   None,
#   '2014-05-13 17:02:02',
#   None,
#   None,
#   None,
#   None,
#   1437763578,
#   0.0),
#  (137,
#   136,
#   'Fred ',
#   'McDonald',
#   None,
#   '2014-05-13 20:44:24',
#   None,
#   None,
#   None,
#   None,
#   1437763252,
#   0.0),
#  (138,
#   137,
#   'kerry ',
#   'grosse',
#   None,
#   '2014-05-14 13:26:30',
#   None,
#   None,
#   None,
#   None,
#   1437762994,
#   0.0),
#  (141,
#   143,
#   'Lalith',
#   'Paulus',
#   'Company17',
#   '2014-05-14 15:43:53',
#   0.0,
#   1.0,
#   None,
#   7.0,
#   1437764400,
#   0.0),
#  (143,
#   144,
#   'Kim',
#   'Novick',
#   None,
#   '2014-05-14 17:01:31',
#   None,
#   None,
#   None,
#   None,
#   1437763342,
#   0.0),
#  (144,
#   145,
#   'Cynthia',
#   'Towers',
#   None,
#   '2014-05-14 19:34:04',
#   None,
#   None,
#   None,
#   None,
#   1437763636,
#   0.0),
#  (145,
#   147,
#   'Kay',
#   'Pruitk',
#   None,
#   '2014-05-15 14:39:06',
#   None,
#   None,
#   None,
#   None,
#   1437763420,
#   0.0),
#  (146,
#   148,
#   'anthony',
#   'jones',
#   'Company18',
#   '2014-05-15 15:10:00',
#   None,
#   1.0,
#   None,
#   None,
#   1437764381,
#   0.0),
#  (147,
#   149,
#   'Mary ',
#   'Allbright',
#   None,
#   '2014-05-16 15:12:17',
#   None,
#   None,
#   None,
#   None,
#   1437762632,
#   0.0),
#  (148,
#   150,
#   'Jeff',
#   'Rudisill',
#   None,
#   '2014-05-18 15:53:42',
#   None,
#   None,
#   None,
#   None,
#   1437763484,
#   0.0),
#  (149,
#   151,
#   'Ollie',
#   'Ward',
#   None,
#   '2014-05-19 17:27:54',
#   None,
#   None,
#   None,
#   None,
#   1437763697,
#   0.0),
#  (150,
#   152,
#   'Edwin',
#   'Colton',
#   None,
#   '2014-05-20 15:21:22',
#   None,
#   None,
#   None,
#   None,
#   1437762801,
#   0.0),
#  (151,
#   153,
#   'James ',
#   'Lewis',
#   None,
#   '2014-05-21 19:40:51',
#   None,
#   None,
#   None,
#   None,
#   1437763174,
#   0.0),
#  (152,
#   154,
#   'Zeljko ',
#   'Vilic',
#   None,
#   '2014-05-22 02:47:53',
#   None,
#   None,
#   None,
#   None,
#   1437763670,
#   0.0),
#  (153,
#   155,
#   'Jack',
#   'Rubinsohn',
#   None,
#   '2014-05-22 04:45:58',
#   None,
#   1.0,
#   None,
#   None,
#   1437763481,
#   0.0),
#  (156,
#   156,
#   'Douglas',
#   'Pircher',
#   None,
#   '2014-05-22 05:10:33',
#   None,
#   None,
#   None,
#   None,
#   1437763402,
#   0.0),
#  (157,
#   157,
#   'JAMES',
#   'CASADO',
#   None,
#   '2014-05-22 17:15:34',
#   None,
#   None,
#   None,
#   None,
#   1437762767,
#   0.0),
#  (158,
#   159,
#   'Charlotte ',
#   'Tarkington',
#   None,
#   '2014-05-23 13:09:38',
#   None,
#   None,
#   None,
#   None,
#   1437763602,
#   0.0),
#  (159,
#   160,
#   'Kay',
#   'Shiflett',
#   None,
#   '2014-05-25 21:50:53',
#   None,
#   None,
#   None,
#   None,
#   1437763538,
#   0.0),
#  (160,
#   161,
#   'Austin',
#   'Stark',
#   None,
#   '2014-05-25 21:54:17',
#   None,
#   None,
#   None,
#   None,
#   1437763566,
#   0.0),
#  (161,
#   162,
#   'Donna',
#   'Murphy',
#   None,
#   '2014-05-25 21:56:13',
#   None,
#   None,
#   None,
#   None,
#   1437763320,
#   0.0),
#  (162,
#   163,
#   'Scott',
#   'Spencer',
#   None,
#   '2014-05-25 21:58:03',
#   None,
#   None,
#   None,
#   None,
#   1437763561,
#   0.0),
#  (163,
#   164,
#   'Vasana ',
#   'Rittharomya',
#   None,
#   '2014-05-25 22:00:34',
#   None,
#   None,
#   None,
#   None,
#   1437763455,
#   0.0),
#  (164,
#   166,
#   'Purley',
#   'Newson',
#   None,
#   '2014-05-26 16:58:02',
#   None,
#   1.0,
#   None,
#   None,
#   1437763334,
#   0.0),
#  (165,
#   167,
#   'Lucy ',
#   'White',
#   None,
#   '2014-05-28 12:49:32',
#   None,
#   None,
#   None,
#   None,
#   1437764210,
#   0.0),
#  (166,
#   168,
#   'Joe',
#   'Roiser',
#   None,
#   '2014-05-29 19:52:20',
#   None,
#   None,
#   None,
#   None,
#   1437763469,
#   0.0),
#  (167,
#   169,
#   'lauren ',
#   'park',
#   None,
#   '2014-05-30 17:17:34',
#   None,
#   None,
#   None,
#   None,
#   1437763373,
#   0.0),
#  (168,
#   170,
#   'Peggy',
#   'Milliman',
#   None,
#   '2014-05-30 18:19:08',
#   None,
#   None,
#   None,
#   None,
#   1437763279,
#   0.0),
#  (169,
#   171,
#   'Ryan',
#   'Naiss',
#   None,
#   '2014-05-30 21:30:07',
#   None,
#   None,
#   None,
#   None,
#   1437763329,
#   0.0),
#  (170,
#   172,
#   'Lorrie ',
#   'Keys',
#   None,
#   '2014-06-01 16:05:24',
#   None,
#   None,
#   None,
#   None,
#   1437763114,
#   0.0),
#  (171,
#   173,
#   'Jere ',
#   'Hancock',
#   None,
#   '2014-06-01 16:07:16',
#   None,
#   None,
#   None,
#   None,
#   1437763012,
#   0.0),
#  (173,
#   174,
#   'Nancy ',
#   'Stuart',
#   None,
#   '2014-06-01 16:09:16',
#   None,
#   None,
#   None,
#   None,
#   1437763587,
#   0.0),
#  (174,
#   175,
#   'Rodney ',
#   'Lueck',
#   None,
#   '2014-06-01 16:14:02',
#   None,
#   None,
#   None,
#   None,
#   1437763194,
#   0.0),
#  (175,
#   176,
#   'Steven ',
#   'Holston',
#   None,
#   '2014-06-02 13:15:45',
#   None,
#   None,
#   None,
#   None,
#   1437763054,
#   0.0),
#  (176,
#   177,
#   'Juanita',
#   'Kelly',
#   None,
#   '2014-06-02 15:36:41',
#   None,
#   None,
#   None,
#   None,
#   1437763106,
#   0.0),
#  (177,
#   179,
#   'sandra',
#   'roberts',
#   None,
#   '2014-06-06 23:51:22',
#   None,
#   None,
#   None,
#   None,
#   1437763460,
#   0.0),
#  (178,
#   181,
#   'Debbie',
#   'Kennon',
#   None,
#   '2014-06-09 00:46:32',
#   None,
#   None,
#   None,
#   None,
#   1437763108,
#   0.0),
#  (179,
#   182,
#   'Phillip ',
#   'Stevens',
#   None,
#   '2014-06-09 12:24:44',
#   None,
#   None,
#   None,
#   None,
#   1437763570,
#   0.0),
#  (180,
#   183,
#   'Gordon ',
#   'Abercrombie',
#   None,
#   '2014-06-09 12:26:14',
#   None,
#   None,
#   None,
#   None,
#   1437762617,
#   0.0),
#  (181,
#   184,
#   'MELODY ',
#   'BURCH',
#   None,
#   '2014-06-09 12:28:20',
#   None,
#   None,
#   None,
#   None,
#   1437762744,
#   0.0),
#  (182,
#   185,
#   'RAUL',
#   'IGNACIO RASCON CARRILLO',
#   None,
#   '2014-06-09 12:30:24',
#   0.0,
#   0.0,
#   None,
#   None,
#   1437763075,
#   0.0),
#  (184,
#   186,
#   'william ',
#   'snelson',
#   None,
#   '2014-06-09 12:32:18',
#   None,
#   None,
#   None,
#   None,
#   1437763557,
#   0.0),
#  (185,
#   187,
#   'MARK ',
#   'ROBINSON',
#   None,
#   '2014-06-09 12:34:41',
#   None,
#   None,
#   None,
#   None,
#   1437763465,
#   0.0),
#  (186,
#   188,
#   'terry',
#   'davis',
#   None,
#   '2014-06-09 22:54:19',
#   None,
#   1.0,
#   None,
#   None,
#   1437762840,
#   0.0),
#  (187,
#   190,
#   'Deborah',
#   'Ferris',
#   None,
#   '2014-06-10 17:10:49',
#   None,
#   None,
#   None,
#   None,
#   1437762917,
#   0.0),
#  (188,
#   192,
#   'Linda',
#   'Galloway',
#   None,
#   '2014-06-11 02:03:37',
#   None,
#   1.0,
#   None,
#   None,
#   1437762950,
#   0.0),
#  (189,
#   193,
#   'Dena ',
#   'Davis',
#   None,
#   '2014-06-12 17:51:51',
#   None,
#   None,
#   None,
#   None,
#   1437762837,
#   0.0),
#  (190,
#   194,
#   'Rebecca',
#   'Mobley',
#   None,
#   '2014-06-12 20:30:53',
#   None,
#   None,
#   None,
#   None,
#   1437763285,
#   0.0),
#  (191,
#   195,
#   'Lisa',
#   'Volaric',
#   None,
#   '2014-06-13 00:50:13',
#   None,
#   None,
#   None,
#   None,
#   1437763677,
#   0.0),
#  (192,
#   196,
#   'marlo',
#   'weems',
#   None,
#   '2014-06-16 05:42:58',
#   None,
#   None,
#   None,
#   None,
#   1437763704,
#   0.0),
#  (193,
#   197,
#   'Sandi',
#   'Novinger',
#   None,
#   '2014-06-16 05:57:43',
#   None,
#   None,
#   None,
#   None,
#   1437763343,
#   0.0),
#  (194,
#   198,
#   'Michael ',
#   'Velez',
#   None,
#   '2014-06-16 14:13:21',
#   None,
#   None,
#   None,
#   None,
#   1437763664,
#   0.0),
#  (195,
#   199,
#   'todd',
#   'Wegner',
#   None,
#   '2014-06-16 14:34:28',
#   None,
#   None,
#   None,
#   None,
#   1437763705,
#   0.0),
#  (196,
#   200,
#   'Florence',
#   'Santiago',
#   None,
#   '2014-06-16 16:48:10',
#   None,
#   None,
#   None,
#   None,
#   1437763496,
#   0.0),
#  (197,
#   201,
#   'Michelle ',
#   'Gentges',
#   None,
#   '2014-06-17 14:05:10',
#   None,
#   None,
#   None,
#   None,
#   1437762966,
#   0.0),
#  (198,
#   202,
#   'MedicAbordable.com',
#   'No. 178',
#   'Company19',
#   '2014-06-17 18:11:35',
#   None,
#   None,
#   None,
#   None,
#   1437764368,
#   0.0),
#  (199,
#   203,
#   'Mark',
#   'Epstein',
#   None,
#   '2014-06-18 19:50:59',
#   None,
#   None,
#   None,
#   None,
#   1437762891,
#   0.0),
#  (200,
#   204,
#   'Dorothy',
#   'Rosenfield',
#   None,
#   '2014-06-19 18:10:51',
#   None,
#   None,
#   None,
#   None,
#   1437763473,
#   0.0),
#  (204,
#   205,
#   'DAVID',
#   'BRAGINSKY',
#   None,
#   '2014-06-20 16:19:35',
#   None,
#   None,
#   None,
#   None,
#   1437762726,
#   0.0),
#  (205,
#   206,
#   'Melinda',
#   'Fortner',
#   None,
#   '2014-06-20 17:21:20',
#   None,
#   None,
#   None,
#   None,
#   1437762930,
#   0.0),
#  (206,
#   207,
#   'Marlys',
#   'Oie',
#   None,
#   '2014-06-23 16:42:09',
#   None,
#   1.0,
#   None,
#   None,
#   1437763352,
#   0.0),
#  (207,
#   208,
#   'Kelly ',
#   'Sandoval',
#   'Company20',
#   '2014-06-26 14:59:17',
#   None,
#   None,
#   None,
#   None,
#   1437764401,
#   0.0),
#  (208,
#   209,
#   'Jeri ',
#   'Tschappat',
#   None,
#   '2014-06-26 15:56:45',
#   None,
#   None,
#   None,
#   None,
#   1437763652,
#   0.0),
#  (209,
#   210,
#   'David ',
#   'Priven',
#   None,
#   '2014-06-26 21:20:43',
#   None,
#   None,
#   None,
#   None,
#   1437763417,
#   0.0),
#  (210,
#   212,
#   'Sean',
#   'Hester',
#   None,
#   '2014-06-28 21:07:52',
#   None,
#   1.0,
#   None,
#   None,
#   1437763038,
#   0.0),
#  (213,
#   213,
#   'Evelyn',
#   'Ho',
#   None,
#   '2014-06-29 06:18:25',
#   None,
#   None,
#   None,
#   None,
#   1437763051,
#   0.0),
#  (222,
#   214,
#   'mary',
#   'vezendy',
#   None,
#   '2014-06-29 15:18:14',
#   None,
#   None,
#   None,
#   None,
#   1437763667,
#   0.0),
#  (223,
#   215,
#   'Vera',
#   'Gardner',
#   None,
#   '2014-06-30 06:02:01',
#   None,
#   1.0,
#   None,
#   None,
#   1437762957,
#   0.0),
#  (224,
#   216,
#   'Ginny ',
#   'Mulligan',
#   None,
#   '2014-06-30 14:24:31',
#   None,
#   None,
#   None,
#   None,
#   1437763317,
#   0.0),
#  (225,
#   222,
#   'Helene',
#   'Johnson',
#   'Company21',
#   '2014-07-07 17:20:11',
#   0.0,
#   1.0,
#   None,
#   8.0,
#   1437764333,
#   0.0),
#  (226,
#   218,
#   'Gareth',
#   'Renkes',
#   None,
#   '2014-07-02 13:30:40',
#   None,
#   1.0,
#   None,
#   None,
#   1437763440,
#   0.0),
#  (228,
#   219,
#   'Christine',
#   'Liberty',
#   None,
#   '2014-07-03 05:10:20',
#   None,
#   1.0,
#   None,
#   None,
#   1437763178,
#   0.0),
#  (229,
#   220,
#   'Jeannie',
#   'Fuller',
#   None,
#   '2014-07-03 18:48:24',
#   None,
#   None,
#   None,
#   None,
#   1437762940,
#   0.0),
#  (230,
#   221,
#   'Kay Kennia ',
#   'Chaveste',
#   None,
#   '2014-07-04 12:42:30',
#   None,
#   None,
#   None,
#   None,
#   1437762784,
#   0.0),
#  (231,
#   223,
#   'Frencey',
#   'Wilson',
#   None,
#   '2014-07-08 14:28:00',
#   None,
#   None,
#   None,
#   None,
#   1437764241,
#   0.0),
#  (232,
#   224,
#   'Kathy ',
#   'Sweet',
#   None,
#   '2014-07-08 14:40:41',
#   None,
#   None,
#   None,
#   None,
#   1437763595,
#   0.0),
#  (233,
#   225,
#   'Stefanie ',
#   'Bedner',
#   None,
#   '2014-07-08 14:42:45',
#   None,
#   None,
#   None,
#   None,
#   1437762690,
#   0.0),
#  (234,
#   226,
#   'James',
#   'Twigg',
#   None,
#   '2014-07-08 19:28:45',
#   None,
#   None,
#   None,
#   None,
#   1437763654,
#   0.0),
#  (235,
#   228,
#   'Tony',
#   "D'Agnolo",
#   None,
#   '2014-07-09 14:40:28',
#   None,
#   None,
#   None,
#   None,
#   1437762825,
#   0.0),
#  (236,
#   234,
#   'Sheila',
#   'Shapiro',
#   None,
#   '2014-07-17 22:02:21',
#   None,
#   None,
#   None,
#   None,
#   1437763533,
#   0.0),
#  (237,
#   229,
#   'Kim',
#   'Torrence',
#   None,
#   '2014-07-10 13:29:00',
#   None,
#   1.0,
#   None,
#   None,
#   1437763627,
#   0.0),
#  (239,
#   230,
#   'Lionel ',
#   'Hernandez',
#   None,
#   '2014-07-10 14:06:56',
#   None,
#   None,
#   None,
#   None,
#   1437763034,
#   0.0),
#  (240,
#   231,
#   'Glyn ',
#   'Burton',
#   None,
#   '2014-07-11 13:03:51',
#   None,
#   None,
#   None,
#   None,
#   1437762748,
#   0.0),
#  (241,
#   232,
#   'Lakeisha',
#   'Jackson',
#   None,
#   '2014-07-11 14:46:42',
#   None,
#   1.0,
#   None,
#   None,
#   1437763081,
#   0.0),
#  (242,
#   233,
#   'Farhana ',
#   'Ahmad',
#   None,
#   '2014-07-14 14:02:57',
#   None,
#   None,
#   None,
#   None,
#   1437762624,
#   0.0),
#  (243,
#   236,
#   'Kathleen',
#   'Fasciano',
#   None,
#   '2014-07-19 20:17:10',
#   None,
#   1.0,
#   None,
#   None,
#   1437762906,
#   0.0),
#  (244,
#   238,
#   'Jael',
#   'Ramadan',
#   None,
#   '2014-07-21 14:40:59',
#   None,
#   None,
#   None,
#   None,
#   1437763431,
#   0.0),
#  (245,
#   239,
#   'John',
#   'ONeill',
#   'Company22',
#   '2014-07-21 15:52:55',
#   None,
#   None,
#   None,
#   None,
#   1437764289,
#   0.0),
#  (246,
#   240,
#   'Robert',
#   'Guillow',
#   None,
#   '2014-07-21 18:06:13',
#   None,
#   None,
#   None,
#   None,
#   1437763001,
#   0.0),
#  (247,
#   242,
#   'Dawn',
#   'Cada',
#   None,
#   '2014-07-21 20:53:01',
#   None,
#   1.0,
#   None,
#   None,
#   1437559400,
#   0.0),
#  (256,
#   243,
#   'CUSTOM ',
#   'METAL WORKS',
#   None,
#   '2014-07-22 17:08:11',
#   None,
#   None,
#   None,
#   None,
#   1437763272,
#   0.0),
#  (257,
#   244,
#   'Isabel',
#   'Roacho',
#   None,
#   '2014-07-22 19:30:12',
#   None,
#   1.0,
#   None,
#   None,
#   1437763459,
#   0.0),
#  (258,
#   245,
#   'Judy ',
#   'Tighe',
#   None,
#   '2014-07-22 20:49:06',
#   None,
#   None,
#   None,
#   None,
#   1437763620,
#   0.0),
#  (259,
#   246,
#   'korey',
#   'pack',
#   None,
#   '2014-07-23 00:00:12',
#   None,
#   1.0,
#   None,
#   None,
#   1437763365,
#   0.0),
#  (260,
#   247,
#   'Victoria',
#   'Sexton',
#   None,
#   '2014-07-23 17:56:45',
#   None,
#   1.0,
#   None,
#   None,
#   1437763530,
#   0.0),
#  (264,
#   248,
#   'Kevin',
#   'Schwenn',
#   None,
#   '2014-07-23 18:40:54',
#   None,
#   1.0,
#   None,
#   None,
#   1437763522,
#   0.0),
#  (265,
#   249,
#   'Betty ',
#   'Moore',
#   None,
#   '2014-07-24 13:04:23',
#   None,
#   None,
#   None,
#   None,
#   1437763297,
#   0.0),
#  (266,
#   250,
#   'Susan',
#   'Krecker',
#   None,
#   '2014-07-24 15:29:38',
#   None,
#   None,
#   None,
#   None,
#   1437763131,
#   0.0),
#  (267,
#   251,
#   'GREG',
#   'BROWN',
#   None,
#   '2014-07-24 15:41:19',
#   None,
#   None,
#   None,
#   None,
#   1437762735,
#   0.0),
#  (268,
#   252,
#   'Jonathan',
#   'Ruiz',
#   'Company23',
#   '2014-07-24 20:14:14',
#   None,
#   1.0,
#   None,
#   None,
#   1437764361,
#   0.0),
#  (270,
#   253,
#   'renee ',
#   'Pallotta',
#   None,
#   '2014-07-25 14:07:54',
#   None,
#   None,
#   None,
#   None,
#   1437763367,
#   0.0),
#  (271,
#   254,
#   'ALICE',
#   'STORTZ',
#   None,
#   '2014-07-26 19:22:37',
#   None,
#   1.0,
#   None,
#   None,
#   1437763581,
#   0.0),
#  (272,
#   255,
#   'Delfina ',
#   'Guzman Estevez',
#   None,
#   '2014-07-27 16:19:02',
#   None,
#   None,
#   None,
#   None,
#   1437763005,
#   0.0),
#  (273,
#   256,
#   'MedicAbordable.com ',
#   'No. 178',
#   None,
#   '2014-07-27 16:22:08',
#   None,
#   None,
#   None,
#   None,
#   1437763339,
#   0.0),
#  (274,
#   257,
#   'Warner ',
#   'Wingler',
#   'Company24',
#   '2014-07-28 14:13:28',
#   None,
#   None,
#   None,
#   None,
#   1437764313,
#   0.0),
#  (275,
#   258,
#   'Nancy',
#   'Anderson',
#   None,
#   '2014-07-28 17:45:22',
#   None,
#   None,
#   None,
#   None,
#   1437762647,
#   0.0),
#  (276,
#   260,
#   'Lester ',
#   'Winebrenner',
#   None,
#   '2014-07-28 21:10:18',
#   None,
#   None,
#   None,
#   None,
#   1437764244,
#   0.0),
#  (278,
#   261,
#   'Burma',
#   'Barnes',
#   None,
#   '2014-07-29 06:01:17',
#   None,
#   1.0,
#   None,
#   None,
#   1437762683,
#   0.0),
#  (279,
#   262,
#   'Ronald',
#   'Davis',
#   None,
#   '2014-07-29 20:27:57',
#   None,
#   None,
#   None,
#   None,
#   1437762839,
#   0.0),
#  (280,
#   263,
#   'Marcia',
#   'Baade',
#   None,
#   '2014-07-30 14:14:51',
#   None,
#   None,
#   None,
#   None,
#   1437762665,
#   0.0),
#  (281,
#   264,
#   'Lynda ',
#   'Froh',
#   None,
#   '2014-07-30 18:34:26',
#   None,
#   None,
#   None,
#   None,
#   1437762937,
#   0.0),
#  (282,
#   266,
#   'Barbara ',
#   'Lemasters',
#   None,
#   '2014-08-01 15:26:29',
#   None,
#   None,
#   None,
#   None,
#   1437763167,
#   0.0),
#  (283,
#   267,
#   'chad ',
#   'ashcraft',
#   None,
#   '2014-08-01 16:27:29',
#   None,
#   None,
#   None,
#   None,
#   1437762659,
#   0.0),
#  (284,
#   268,
#   'Empire',
#   'Medical',
#   'Company25',
#   '2014-08-01 18:26:06',
#   None,
#   None,
#   None,
#   None,
#   1437764328,
#   0.0),
#  (285,
#   269,
#   'rebecca',
#   'walker',
#   None,
#   '2014-08-02 03:27:37',
#   None,
#   1.0,
#   None,
#   None,
#   1437763688,
#   0.0),
#  (286,
#   270,
#   'Martha',
#   'Madera',
#   None,
#   '2014-08-02 19:44:04',
#   None,
#   1.0,
#   None,
#   None,
#   1437763203,
#   0.0),
#  (287,
#   272,
#   'Leo',
#   'Pak',
#   None,
#   '2014-08-06 11:06:51',
#   None,
#   None,
#   None,
#   None,
#   1437763366,
#   0.0),
#  (288,
#   273,
#   'Julie ',
#   'Velasco',
#   None,
#   '2014-08-06 14:07:30',
#   None,
#   None,
#   None,
#   None,
#   1437763663,
#   0.0),
#  (289,
#   274,
#   'Aimee',
#   'Fuselier',
#   None,
#   '2014-08-07 00:40:45',
#   None,
#   1.0,
#   None,
#   None,
#   1437762944,
#   0.0),
#  (290,
#   275,
#   'Amy ',
#   'Williams',
#   None,
#   '2014-08-11 15:04:20',
#   None,
#   None,
#   None,
#   None,
#   1437764226,
#   0.0),
#  (291,
#   276,
#   'Gloria',
#   'Gordon',
#   None,
#   '2014-08-11 15:43:24',
#   None,
#   None,
#   None,
#   None,
#   1437762981,
#   0.0),
#  (293,
#   277,
#   'Marvin',
#   'Hernandez',
#   None,
#   '2014-08-14 02:59:05',
#   None,
#   None,
#   None,
#   None,
#   1437763035,
#   0.0),
#  (294,
#   279,
#   'adam',
#   'henninger',
#   None,
#   '2014-08-14 11:58:22',
#   None,
#   1.0,
#   None,
#   None,
#   1437763030,
#   0.0),
#  (295,
#   281,
#   'Lisa ',
#   'Ryder',
#   None,
#   '2014-08-14 21:13:27',
#   None,
#   None,
#   None,
#   None,
#   1437763488,
#   0.0),
#  (296,
#   282,
#   'Valentine',
#   'Jideofor',
#   'Company26',
#   '2014-08-15 04:11:54',
#   None,
#   1.0,
#   None,
#   None,
#   1437764298,
#   0.0),
#  (297,
#   283,
#   'Sara',
#   'Rangel ',
#   None,
#   '2014-08-15 23:26:03',
#   None,
#   1.0,
#   None,
#   None,
#   1437763434,
#   0.0),
#  (298,
#   284,
#   'Walter ',
#   'Mitchell',
#   'Company10',
#   '2014-08-17 18:21:56',
#   None,
#   1.0,
#   None,
#   None,
#   1437764390,
#   0.0),
#  (299,
#   286,
#   'Bill',
#   'Bradford',
#   None,
#   '2014-08-18 14:47:12',
#   None,
#   1.0,
#   None,
#   None,
#   1437762725,
#   0.0),
#  (300,
#   287,
#   'Rob',
#   'Sanchez',
#   'Company27',
#   '2014-08-18 16:06:01',
#   None,
#   1.0,
#   None,
#   None,
#   1437764292,
#   0.0),
#  (302,
#   288,
#   'GARY',
#   'HEIDMAN',
#   None,
#   '2014-08-18 16:55:27',
#   None,
#   1.0,
#   None,
#   None,
#   1437763025,
#   0.0),
#  (303,
#   289,
#   'Joann',
#   'Brophy',
#   None,
#   '2014-08-20 15:43:38',
#   0.0,
#   0.0,
#   None,
#   None,
#   1437762734,
#   0.0),
#  (304,
#   290,
#   'Lona',
#   'Strawbridge',
#   None,
#   '2014-08-20 17:00:09',
#   None,
#   None,
#   None,
#   None,
#   1437763584,
#   0.0),
#  (305,
#   291,
#   'Monte',
#   'hutchins',
#   None,
#   '2014-08-20 21:54:10',
#   None,
#   None,
#   None,
#   None,
#   1437763073,
#   0.0),
#  (306,
#   292,
#   'Bernie ',
#   'Singletary',
#   None,
#   '2014-08-21 19:54:11',
#   None,
#   None,
#   None,
#   None,
#   1437763544,
#   0.0),
#  (307,
#   293,
#   'yesucher ',
#   'marguleis',
#   None,
#   '2014-08-24 15:08:08',
#   None,
#   None,
#   None,
#   None,
#   1437763220,
#   0.0),
#  (308,
#   294,
#   'Deborah ',
#   'Evans',
#   None,
#   '2014-08-24 15:09:43',
#   None,
#   None,
#   None,
#   None,
#   1437762899,
#   0.0),
#  (312,
#   295,
#   'Ann ',
#   'Duckworth',
#   None,
#   '2014-08-24 15:12:32',
#   None,
#   None,
#   None,
#   None,
#   1437762864,
#   0.0),
#  (313,
#   296,
#   'Michaela',
#   'Schmitz',
#   None,
#   '2014-08-24 20:10:10',
#   None,
#   1.0,
#   None,
#   None,
#   1437763517,
#   0.0),
#  (316,
#   297,
#   'Vito',
#   'Laudicina',
#   None,
#   '2014-08-25 13:57:13',
#   None,
#   None,
#   None,
#   None,
#   1437763151,
#   0.0),
#  (317,
#   298,
#   'Tammy',
#   'Whiting',
#   'Company28',
#   '2014-08-25 15:45:23',
#   None,
#   1.0,
#   None,
#   None,
#   1437764385,
#   0.0),
#  (319,
#   299,
#   'Teresa',
#   'Guss',
#   None,
#   '2014-08-25 18:07:59',
#   None,
#   None,
#   None,
#   None,
#   1437763003,
#   0.0),
#  (320,
#   300,
#   'Debra',
#   'Luciani',
#   None,
#   '2014-08-25 18:37:40',
#   None,
#   1.0,
#   None,
#   None,
#   1437763193,
#   0.0),
#  (321,
#   301,
#   'lavonne',
#   'Larkin',
#   None,
#   '2014-08-25 20:30:58',
#   None,
#   None,
#   None,
#   None,
#   1437763148,
#   0.0),
#  (322,
#   302,
#   'Gary',
#   'Schaeffer',
#   'Company29',
#   '2014-08-26 16:52:16',
#   None,
#   None,
#   None,
#   None,
#   1437764344,
#   0.0),
#  (323,
#   303,
#   'Ann',
#   'Blackmon',
#   None,
#   '2014-08-26 17:24:57',
#   None,
#   None,
#   None,
#   None,
#   1437762706,
#   0.0),
#  (324,
#   304,
#   'Alexander',
#   'Manly',
#   None,
#   '2014-08-26 19:24:16',
#   None,
#   1.0,
#   None,
#   None,
#   1437763215,
#   0.0),
#  (336,
#   305,
#   'Leticia ',
#   'Lacson',
#   None,
#   '2014-08-26 20:55:04',
#   None,
#   None,
#   None,
#   None,
#   1437763144,
#   0.0),
#  (337,
#   306,
#   'Dorothy',
#   'Brown',
#   None,
#   '2014-08-27 18:02:13',
#   None,
#   None,
#   None,
#   None,
#   1437559378,
#   0.0),
#  (344,
#   307,
#   'Mike',
#   'Walsh',
#   None,
#   '2014-08-27 19:10:10',
#   None,
#   None,
#   None,
#   None,
#   1437763692,
#   0.0),
#  (346,
#   308,
#   'James ',
#   'James ',
#   None,
#   '2014-08-27 19:30:16',
#   None,
#   None,
#   None,
#   None,
#   1437763086,
#   0.0),
#  (347,
#   309,
#   'Linda',
#   'Lyonf',
#   None,
#   '2014-08-27 20:27:20',
#   None,
#   None,
#   None,
#   None,
#   1437763198,
#   0.0),
#  (348,
#   310,
#   'Ramachandra Murty',
#   'Krishnamsetty',
#   None,
#   '2014-08-28 17:57:20',
#   None,
#   None,
#   None,
#   None,
#   1437763134,
#   0.0),
#  (349,
#   311,
#   'Tony ',
#   'Bousalman',
#   'Company30',
#   '2014-08-29 14:02:33',
#   None,
#   None,
#   None,
#   None,
#   1437764403,
#   0.0),
#  (350,
#   312,
#   'Anne',
#   'Montez',
#   None,
#   '2014-08-30 18:41:47',
#   None,
#   1.0,
#   None,
#   None,
#   1437763289,
#   0.0),
#  (353,
#   313,
#   'earl',
#   'charlery',
#   None,
#   '2014-08-31 12:22:16',
#   None,
#   None,
#   None,
#   None,
#   1437762783,
#   0.0),
#  (354,
#   314,
#   'Ali ',
#   'Malik',
#   None,
#   '2014-08-31 16:59:44',
#   None,
#   None,
#   None,
#   None,
#   1437763208,
#   0.0),
#  (355,
#   315,
#   'maria ',
#   'gonzalez',
#   None,
#   '2014-09-01 13:26:29',
#   None,
#   None,
#   None,
#   None,
#   1437762977,
#   0.0),
#  (356,
#   316,
#   'Ed',
#   'Hartowicz',
#   None,
#   '2014-09-02 12:48:41',
#   None,
#   None,
#   None,
#   None,
#   1437763018,
#   0.0),
#  (357,
#   317,
#   'Nellie',
#   'Bernard',
#   None,
#   '2014-09-02 13:25:43',
#   None,
#   None,
#   None,
#   None,
#   1437762700,
#   0.0),
#  (358,
#   319,
#   'Gloria',
#   'Fontanilla',
#   None,
#   '2014-09-03 18:04:58',
#   None,
#   1.0,
#   None,
#   None,
#   1437762925,
#   0.0),
#  (359,
#   321,
#   'Kim',
#   'Erickson',
#   None,
#   '2014-09-03 19:44:59',
#   None,
#   None,
#   None,
#   None,
#   1437762892,
#   0.0),
#  (360,
#   323,
#   'Howard',
#   'Calloway',
#   None,
#   '2014-09-04 19:45:38',
#   None,
#   None,
#   None,
#   None,
#   1437762752,
#   0.0),
#  (361,
#   324,
#   'Jesse',
#   'Tramamell',
#   None,
#   '2014-09-05 16:04:16',
#   None,
#   None,
#   None,
#   None,
#   1437763640,
#   0.0),
#  (362,
#   325,
#   'Mark ',
#   'Taylor',
#   None,
#   '2014-09-07 16:21:57',
#   None,
#   None,
#   None,
#   None,
#   1437763607,
#   0.0),
#  (363,
#   326,
#   'Pam ',
#   'Napier',
#   None,
#   '2014-09-07 16:23:28',
#   None,
#   None,
#   None,
#   None,
#   1437763330,
#   0.0),
#  (364,
#   328,
#   'Susan ',
#   'Wood',
#   None,
#   '2014-09-10 14:14:46',
#   None,
#   None,
#   None,
#   None,
#   1437764254,
#   0.0),
#  (365,
#   329,
#   'Ryan',
#   'Haggard',
#   None,
#   '2014-09-10 16:39:39',
#   None,
#   1.0,
#   None,
#   None,
#   1437763006,
#   0.0),
#  (366,
#   330,
#   'Kevin',
#   'Wolf',
#   None,
#   '2014-09-11 06:42:43',
#   None,
#   1.0,
#   None,
#   None,
#   1437764250,
#   0.0),
#  (368,
#   331,
#   'Julie ',
#   'Moran',
#   None,
#   '2014-09-11 20:53:16',
#   None,
#   None,
#   None,
#   None,
#   1437763305,
#   0.0),
#  (369,
#   332,
#   'Zadie ',
#   'Carter',
#   None,
#   '2014-09-12 15:53:12',
#   None,
#   None,
#   None,
#   None,
#   1437762766,
#   0.0),
#  (370,
#   333,
#   'Lucinda',
#   'King',
#   None,
#   '2014-09-12 19:07:13',
#   None,
#   1.0,
#   None,
#   None,
#   1437763116,
#   0.0),
#  (376,
#   334,
#   'Natasha',
#   'Waldhalm',
#   None,
#   '2014-09-12 20:15:27',
#   None,
#   None,
#   None,
#   None,
#   1437763683,
#   0.0),
#  (377,
#   337,
#   'sean ',
#   'kearney',
#   'Company31',
#   '2014-09-15 13:38:34',
#   None,
#   None,
#   None,
#   None,
#   1437764395,
#   0.0),
#  (378,
#   338,
#   'Louise ',
#   'Alger',
#   None,
#   '2014-09-15 13:40:04',
#   None,
#   None,
#   None,
#   None,
#   1437762630,
#   0.0),
#  (379,
#   339,
#   'Robert ',
#   'Armstrong',
#   None,
#   '2014-09-15 13:43:22',
#   None,
#   None,
#   None,
#   None,
#   1437762654,
#   0.0),
#  (380,
#   340,
#   'Rev. Rickey ',
#   'McAfee',
#   None,
#   '2014-09-15 13:45:47',
#   None,
#   None,
#   None,
#   None,
#   1437763243,
#   0.0),
#  (381,
#   342,
#   'John',
#   'Adt',
#   None,
#   '2014-09-16 14:22:01',
#   None,
#   None,
#   None,
#   None,
#   1437762620,
#   0.0),
#  (382,
#   343,
#   'Barbara',
#   'Larson',
#   None,
#   '2014-09-16 15:55:02',
#   None,
#   None,
#   None,
#   None,
#   1437763149,
#   0.0),
#  (383,
#   344,
#   'ANDREA',
#   'CASTRO',
#   None,
#   '2014-09-17 05:03:23',
#   None,
#   None,
#   None,
#   None,
#   1437762771,
#   0.0),
#  (384,
#   345,
#   'Duy ',
#   'Phan',
#   None,
#   '2014-09-18 02:55:39',
#   None,
#   None,
#   None,
#   None,
#   1437763393,
#   0.0),
#  (387,
#   346,
#   'Kathy ',
#   'Hendrix',
#   None,
#   '2014-09-18 14:10:53',
#   None,
#   None,
#   None,
#   None,
#   1437763029,
#   0.0),
#  (388,
#   347,
#   'chaf ',
#   'zalenski',
#   None,
#   '2014-09-18 14:14:58',
#   None,
#   None,
#   None,
#   None,
#   1437764264,
#   0.0),
#  (389,
#   348,
#   'Patricia M',
#   'Bomar',
#   None,
#   '2014-09-18 19:17:00',
#   None,
#   None,
#   None,
#   None,
#   1437762711,
#   0.0),
#  (390,
#   349,
#   'mary',
#   'sautter',
#   'Company32',
#   '2014-09-22 13:54:41',
#   None,
#   1.0,
#   None,
#   None,
#   1437764305,
#   0.0),
#  (391,
#   350,
#   'Aphel',
#   'Albritton',
#   None,
#   '2014-09-22 17:11:46',
#   None,
#   None,
#   None,
#   None,
#   1437762626,
#   0.0),
#  (392,
#   351,
#   'Randy ',
#   'McFadden',
#   None,
#   '2014-09-22 19:26:40',
#   None,
#   None,
#   None,
#   None,
#   1437763257,
#   0.0),
#  (393,
#   353,
#   'Maria ',
#   'Vizcaino',
#   None,
#   '2014-09-23 13:43:39',
#   None,
#   None,
#   None,
#   None,
#   1437763675,
#   0.0),
#  (394,
#   355,
#   'Dave ',
#   'Howell',
#   None,
#   '2014-09-28 16:41:45',
#   None,
#   None,
#   None,
#   None,
#   1437763060,
#   0.0),
#  (395,
#   356,
#   'Teri ',
#   'Pendegraft',
#   None,
#   '2014-09-28 16:44:05',
#   None,
#   None,
#   None,
#   None,
#   1437763384,
#   0.0),
#  (396,
#   357,
#   'Ivan ',
#   'Aldred',
#   None,
#   '2014-09-28 16:45:48',
#   None,
#   None,
#   None,
#   None,
#   1437762627,
#   0.0),
#  (397,
#   358,
#   'Wilford ',
#   'Schreiber',
#   None,
#   '2014-09-28 16:47:41',
#   None,
#   None,
#   None,
#   None,
#   1437763520,
#   0.0),
#  (398,
#   359,
#   'Keva ',
#   'Johnson',
#   None,
#   '2014-09-28 16:51:52',
#   None,
#   None,
#   None,
#   None,
#   1437763091,
#   0.0),
#  (399,
#   360,
#   'DEBERA ',
#   'LOVIN',
#   None,
#   '2014-09-28 16:53:33',
#   None,
#   None,
#   None,
#   None,
#   1437763192,
#   0.0),
#  (400,
#   361,
#   'Maria',
#   'Santos',
#   None,
#   '2014-09-28 16:55:27',
#   None,
#   None,
#   None,
#   None,
#   1437763499,
#   0.0),
#  (401,
#   362,
#   'Julia',
#   'Himely',
#   None,
#   '2014-09-28 16:57:14',
#   None,
#   None,
#   None,
#   None,
#   1437763047,
#   0.0),
#  (402,
#   363,
#   'JAMES',
#   'POMEROY JR.',
#   None,
#   '2014-09-29 03:56:56',
#   None,
#   None,
#   None,
#   None,
#   1437763411,
#   0.0),
#  (403,
#   364,
#   'judith ',
#   'williams',
#   None,
#   '2014-09-29 13:16:16',
#   None,
#   None,
#   None,
#   None,
#   1437764232,
#   0.0),
#  (404,
#   365,
#   'April ',
#   'Davis',
#   None,
#   '2014-09-29 13:19:45',
#   None,
#   None,
#   None,
#   None,
#   1437762836,
#   0.0),
#  (405,
#   366,
#   'Evelyn',
#   'Duncan',
#   None,
#   '2014-09-29 23:48:14',
#   None,
#   None,
#   None,
#   None,
#   1437762868,
#   0.0),
#  (406,
#   367,
#   'Gail',
#   'Whitney Allen',
#   None,
#   '2014-09-30 19:14:03',
#   None,
#   None,
#   None,
#   None,
#   1437764213,
#   0.0),
#  (408,
#   368,
#   'Julie',
#   'Mitchler',
#   None,
#   '2014-10-01 17:11:54',
#   None,
#   1.0,
#   None,
#   None,
#   1437763284,
#   0.0),
#  (409,
#   369,
#   'charles ',
#   'thompson',
#   None,
#   '2014-10-01 18:18:13',
#   None,
#   None,
#   None,
#   None,
#   1437763615,
#   0.0),
#  (410,
#   370,
#   'Jay',
#   'Goeloe',
#   None,
#   '2014-10-01 18:29:17',
#   None,
#   None,
#   None,
#   None,
#   1437762972,
#   0.0),
#  (411,
#   371,
#   'Martha',
#   'Dudley',
#   None,
#   '2014-10-02 10:32:55',
#   None,
#   None,
#   None,
#   None,
#   1437762867,
#   0.0),
#  (412,
#   372,
#   'sid',
#   'khosla',
#   'Company33',
#   '2014-10-02 21:01:28',
#   None,
#   1.0,
#   None,
#   None,
#   1437764438,
#   0.0),
#  (415,
#   373,
#   'julie',
#   'gallai',
#   None,
#   '2014-10-03 07:05:13',
#   None,
#   1.0,
#   None,
#   None,
#   1437762948,
#   0.0),
#  (417,
#   374,
#   'Stewart ',
#   'tauscher',
#   None,
#   '2014-10-05 19:51:16',
#   None,
#   None,
#   None,
#   None,
#   1437763605,
#   0.0),
#  (418,
#   375,
#   'Ron',
#   'Gilbert',
#   None,
#   '2014-10-05 19:59:38',
#   None,
#   None,
#   None,
#   None,
#   1437762970,
#   0.0),
#  (419,
#   376,
#   'Krinshnan ',
#   'Sivapakkiam',
#   'Company34',
#   '2014-10-05 20:01:51',
#   None,
#   None,
#   None,
#   None,
#   1437764406,
#   0.0),
#  (420,
#   377,
#   'Judy ',
#   'Williams',
#   None,
#   '2014-10-06 13:56:35',
#   None,
#   None,
#   None,
#   None,
#   1437764233,
#   0.0),
#  (421,
#   378,
#   'Carolyn ',
#   'Yarber',
#   None,
#   '2014-10-06 14:23:04',
#   None,
#   None,
#   None,
#   None,
#   1437764259,
#   0.0),
#  (422,
#   379,
#   'marc',
#   'brown',
#   None,
#   '2014-10-06 15:47:00',
#   None,
#   1.0,
#   None,
#   None,
#   1437762736,
#   0.0),
#  (424,
#   382,
#   'Randall',
#   'Wagstaff',
#   None,
#   '2014-10-06 20:55:49',
#   None,
#   None,
#   None,
#   None,
#   1437763682,
#   0.0),
#  (425,
#   383,
#   'Dorothy',
#   'Marue',
#   None,
#   '2014-10-06 21:03:28',
#   None,
#   None,
#   None,
#   None,
#   1437763231,
#   0.0),
#  (426,
#   384,
#   'Danny ',
#   'mills',
#   None,
#   '2014-10-06 21:31:09',
#   None,
#   None,
#   None,
#   None,
#   1437763280,
#   0.0),
#  (427,
#   385,
#   'William',
#   'York',
#   None,
#   '2014-10-07 13:48:02',
#   None,
#   None,
#   None,
#   None,
#   1437764260,
#   0.0),
#  (428,
#   386,
#   'helen',
#   'hughes',
#   None,
#   '2014-10-21 09:01:08',
#   None,
#   None,
#   None,
#   None,
#   1437763063,
#   0.0),
#  (429,
#   387,
#   'Natalie',
#   'Ohara',
#   None,
#   '2014-10-21 15:14:04',
#   None,
#   None,
#   None,
#   None,
#   1437763349,
#   0.0),
#  (430,
#   388,
#   'lisa',
#   'harris',
#   'Company35',
#   '2014-10-22 13:27:01',
#   None,
#   None,
#   None,
#   None,
#   1437764337,
#   0.0),
#  (431,
#   390,
#   'Janick ',
#   'Gaudreau',
#   'Company36',
#   '2014-10-22 18:45:23',
#   None,
#   None,
#   None,
#   None,
#   1437764404,
#   0.0),
#  (432,
#   391,
#   'James',
#   'Dempsey',
#   None,
#   '2014-10-22 19:17:34',
#   None,
#   None,
#   None,
#   None,
#   1437762849,
#   0.0),
#  (433,
#   392,
#   'Blanche',
#   'Rose',
#   'Company37',
#   '2014-10-23 01:08:41',
#   None,
#   1.0,
#   None,
#   None,
#   1437764278,
#   0.0),
#  (434,
#   393,
#   'henrietta ',
#   'cullinane',
#   None,
#   '2014-10-23 14:10:43',
#   None,
#   None,
#   None,
#   None,
#   1437762821,
#   0.0),
#  (435,
#   394,
#   'Earlin',
#   'Turner',
#   None,
#   '2014-10-23 21:05:45',
#   None,
#   None,
#   None,
#   None,
#   1437763653,
#   0.0),
#  (436,
#   396,
#   'Mary',
#   'Datoc',
#   None,
#   '2014-10-26 15:39:18',
#   None,
#   None,
#   None,
#   None,
#   1437559492,
#   0.0),
#  (454,
#   397,
#   'Sonia ',
#   'Velez',
#   None,
#   '2014-10-27 14:20:22',
#   None,
#   None,
#   None,
#   None,
#   1437763666,
#   0.0),
#  (455,
#   398,
#   'Marisel',
#   'Galarza',
#   'Company38',
#   '2014-10-27 15:00:38',
#   None,
#   1.0,
#   None,
#   None,
#   1437764366,
#   0.0),
#  (457,
#   399,
#   'Cornelius',
#   'Riegel',
#   None,
#   '2014-10-27 15:29:41',
#   None,
#   None,
#   None,
#   None,
#   1437763449,
#   0.0),
#  (458,
#   400,
#   'Helen',
#   'Mayes',
#   None,
#   '2014-10-27 17:03:43',
#   None,
#   None,
#   None,
#   None,
#   1437763240,
#   0.0),
#  (459,
#   401,
#   'Ivory ',
#   'Field',
#   None,
#   '2014-10-27 19:07:37',
#   None,
#   None,
#   None,
#   None,
#   1437762920,
#   0.0),
#  (460,
#   402,
#   'Francisco',
#   'Lam',
#   None,
#   '2014-10-27 22:11:57',
#   None,
#   1.0,
#   None,
#   None,
#   1437764379,
#   0.0),
#  (461,
#   403,
#   'Jana',
#   'Mane',
#   None,
#   '2014-10-29 13:40:02',
#   None,
#   None,
#   None,
#   None,
#   1437559989,
#   0.0),
#  (476,
#   404,
#   'Carll',
#   'Asbury',
#   None,
#   '2014-10-29 15:06:42',
#   None,
#   None,
#   None,
#   None,
#   1437762658,
#   0.0),
#  (477,
#   405,
#   'Barbara',
#   'Dartez',
#   None,
#   '2014-10-29 17:18:34',
#   None,
#   None,
#   None,
#   None,
#   1437762831,
#   0.0),
#  (478,
#   406,
#   'jennifer',
#   'knowles',
#   None,
#   '2014-11-01 17:29:45',
#   None,
#   None,
#   None,
#   None,
#   1437763124,
#   0.0),
#  (479,
#   407,
#   'John',
#   'Belluomo',
#   None,
#   '2014-11-01 17:51:30',
#   None,
#   None,
#   None,
#   None,
#   1437762692,
#   0.0),
#  (480,
#   408,
#   'Stacey',
#   'Dierksmeier',
#   None,
#   '2014-11-02 01:25:31',
#   None,
#   1.0,
#   None,
#   None,
#   1437762854,
#   0.0),
#  (481,
#   409,
#   'Donald ',
#   'Ayres',
#   None,
#   '2014-11-02 15:56:43',
#   None,
#   None,
#   None,
#   None,
#   1437762664,
#   0.0),
#  (482,
#   411,
#   'Maribel',
#   'Stinson',
#   None,
#   '2014-11-04 00:49:54',
#   None,
#   None,
#   None,
#   None,
#   1437763575,
#   0.0),
#  (483,
#   412,
#   'Theresa',
#   'Ryan',
#   None,
#   '2014-11-04 00:50:19',
#   None,
#   None,
#   None,
#   None,
#   1437560373,
#   0.0),
#  (492,
#   413,
#   'jim',
#   'stulce',
#   None,
#   '2014-11-04 12:07:43',
#   None,
#   None,
#   None,
#   None,
#   1437763589,
#   0.0),
#  (493,
#   414,
#   'Steven',
#   'LeBlanc',
#   None,
#   '2014-11-04 17:12:37',
#   0.0,
#   0.0,
#   None,
#   None,
#   1437763157,
#   0.0),
#  (494,
#   415,
#   'Stacy',
#   'Harrison',
#   None,
#   '2014-11-04 20:49:36',
#   None,
#   None,
#   None,
#   None,
#   1437763014,
#   0.0),
#  (495,
#   416,
#   'Susan',
#   'Flood',
#   None,
#   '2014-11-04 21:47:06',
#   None,
#   None,
#   None,
#   None,
#   1437762923,
#   0.0),
#  (496,
#   417,
#   'Richard',
#   'McCabe',
#   None,
#   '2014-11-05 17:15:33',
#   None,
#   None,
#   None,
#   None,
#   1437763245,
#   0.0),
#  (498,
#   418,
#   'Caren',
#   'Duda',
#   None,
#   '2014-11-05 22:46:32',
#   None,
#   None,
#   None,
#   None,
#   1437762866,
#   0.0),
#  (500,
#   419,
#   'Steve',
#   'Didio',
#   None,
#   '2014-11-05 23:54:46',
#   None,
#   None,
#   None,
#   None,
#   1437559519,
#   0.0),
#  (502,
#   420,
#   'karen',
#   'Groce',
#   None,
#   '2014-11-06 18:11:46',
#   None,
#   None,
#   None,
#   None,
#   1437762993,
#   0.0),
#  (503,
#   421,
#   'Lillie ',
#   'Gathing',
#   None,
#   '2014-11-06 20:03:16',
#   None,
#   None,
#   None,
#   None,
#   1437762961,
#   0.0),
#  (504,
#   422,
#   'William',
#   'Barczy',
#   'Company39',
#   '2014-11-07 04:09:38',
#   None,
#   1.0,
#   None,
#   None,
#   1437764290,
#   0.0),
#  (505,
#   426,
#   'Liduvina',
#   'Travieso',
#   None,
#   '2014-11-07 20:39:19',
#   None,
#   1.0,
#   None,
#   None,
#   1437763643,
#   0.0),
#  (506,
#   427,
#   'Virginia',
#   'Schroyer',
#   None,
#   '2014-11-08 15:14:16',
#   None,
#   None,
#   None,
#   None,
#   1437763521,
#   0.0),
#  (507,
#   428,
#   'Meyet',
#   'Weiss',
#   None,
#   '2014-11-09 09:39:06',
#   None,
#   1.0,
#   None,
#   None,
#   1437560670,
#   0.0),
#  (512,
#   430,
#   'Marie ',
#   'Baer',
#   None,
#   '2014-11-09 16:58:12',
#   None,
#   None,
#   None,
#   None,
#   1437762670,
#   0.0),
#  (513,
#   432,
#   'Jason',
#   'Arp',
#   None,
#   '2014-11-10 16:43:04',
#   None,
#   None,
#   None,
#   None,
#   1437762656,
#   0.0),
#  (514,
#   433,
#   'Dosinda',
#   'Perez',
#   None,
#   '2014-11-12 00:36:16',
#   None,
#   1.0,
#   None,
#   None,
#   1437763386,
#   0.0),
#  (515,
#   434,
#   'James',
#   'Doheny',
#   None,
#   '2014-11-12 15:11:08',
#   None,
#   1.0,
#   None,
#   None,
#   1437762857,
#   0.0),
#  (516,
#   435,
#   'Luis',
#   'Castro',
#   None,
#   '2014-11-12 15:36:24',
#   None,
#   None,
#   None,
#   None,
#   1437762772,
#   0.0),
#  (517,
#   436,
#   'Abraham',
#   'Pollak',
#   None,
#   '2014-11-12 15:47:38',
#   None,
#   1.0,
#   None,
#   None,
#   1437763410,
#   0.0),
#  (519,
#   438,
#   'Elizabeth',
#   'Field',
#   None,
#   '2014-11-12 22:35:02',
#   None,
#   None,
#   None,
#   None,
#   1437762918,
#   0.0),
#  (520,
#   440,
#   'Cecilia',
#   'Cervantes',
#   None,
#   '2014-11-13 22:23:21',
#   None,
#   None,
#   None,
#   None,
#   1437762778,
#   0.0),
#  (521,
#   441,
#   'sara',
#   'sajdak',
#   None,
#   '2014-11-14 00:04:31',
#   None,
#   None,
#   None,
#   None,
#   1437763491,
#   0.0),
#  (522,
#   442,
#   'David',
#   'Oconnell',
#   None,
#   '2014-11-14 14:57:53',
#   0.0,
#   0.0,
#   None,
#   None,
#   1437763346,
#   0.0),
#  (524,
#   443,
#   'Bruce',
#   'McKechnie',
#   None,
#   '2014-11-14 15:30:31',
#   None,
#   None,
#   None,
#   None,
#   1437763261,
#   0.0),
#  (525,
#   444,
#   'JAMES ',
#   'HURST',
#   None,
#   '2014-11-14 16:30:27',
#   None,
#   None,
#   None,
#   None,
#   1437763070,
#   0.0),
#  (526,
#   445,
#   'Rob',
#   'Coty',
#   None,
#   '2014-11-14 17:11:55',
#   None,
#   None,
#   None,
#   None,
#   1437762815,
#   0.0),
#  (527,
#   446,
#   'Daniel',
#   'Lobato',
#   None,
#   '2014-11-15 08:53:19',
#   None,
#   1.0,
#   None,
#   None,
#   1437763185,
#   0.0),
#  (528,
#   447,
#   'Hector ',
#   'Aguilar',
#   None,
#   '2014-11-16 18:05:59',
#   None,
#   None,
#   None,
#   None,
#   1437762622,
#   0.0),
#  (529,
#   448,
#   'Tissa',
#   'Abeyratne',
#   None,
#   '2014-11-17 14:49:18',
#   None,
#   1.0,
#   None,
#   None,
#   1437762618,
#   0.0),
#  (530,
#   449,
#   'Hope',
#   'Swilley',
#   None,
#   '2014-11-17 20:12:28',
#   None,
#   None,
#   None,
#   None,
#   1437763597,
#   0.0),
#  (531,
#   450,
#   'Mark',
#   'Rosequist',
#   None,
#   '2014-11-18 17:18:49',
#   None,
#   None,
#   None,
#   None,
#   1437763475,
#   0.0),
#  (533,
#   451,
#   'Shirley',
#   'Johnson',
#   None,
#   '2014-11-18 18:17:12',
#   None,
#   None,
#   None,
#   None,
#   1437763093,
#   0.0),
#  (539,
#   452,
#   'Jason',
#   'Freeman',
#   None,
#   '2014-11-18 20:07:30',
#   None,
#   None,
#   None,
#   None,
#   1437762934,
#   0.0),
#  (540,
#   453,
#   'Herbert M',
#   'Levy',
#   None,
#   '2014-11-18 23:59:45',
#   None,
#   1.0,
#   None,
#   None,
#   1437763172,
#   0.0),
#  (544,
#   454,
#   'ANGELA',
#   'BURT',
#   'Company40',
#   '2014-11-19 14:48:03',
#   None,
#   None,
#   None,
#   None,
#   1437764369,
#   0.0),
#  (545,
#   455,
#   'Genesis',
#   'Dominguez',
#   None,
#   '2014-11-19 14:55:52',
#   None,
#   None,
#   None,
#   None,
#   1437762858,
#   0.0),
#  (546,
#   457,
#   'Jessica',
#   'Machado',
#   None,
#   '2014-11-19 21:36:10',
#   None,
#   1.0,
#   None,
#   None,
#   1437763199,
#   0.0),
#  (547,
#   458,
#   'Katherine ',
#   'Gordon',
#   None,
#   '2014-11-20 18:59:52',
#   None,
#   None,
#   None,
#   None,
#   1437762983,
#   0.0),
#  (548,
#   459,
#   'Ronald',
#   'Daniels',
#   None,
#   '2014-11-20 21:35:56',
#   None,
#   None,
#   None,
#   None,
#   1437762829,
#   0.0),
#  (549,
#   461,
#   'Lynda',
#   'Porter',
#   None,
#   '2014-11-21 23:29:37',
#   None,
#   None,
#   None,
#   None,
#   1437763413,
#   0.0),
#  (550,
#   462,
#   'Don',
#   'Goforth',
#   'Company41',
#   '2014-11-22 21:34:07',
#   None,
#   1.0,
#   None,
#   None,
#   1437764340,
#   0.0),
#  (552,
#   463,
#   'JIm',
#   'Rothenberger',
#   None,
#   '2014-11-23 16:53:48',
#   None,
#   None,
#   None,
#   None,
#   1437763477,
#   0.0),
#  (553,
#   464,
#   'Rose ',
#   'McCluney',
#   None,
#   '2014-11-23 16:55:10',
#   None,
#   None,
#   None,
#   None,
#   1437763249,
#   0.0),
#  (554,
#   465,
#   'Ashley',
#   'Bourdeau',
#   None,
#   '2014-11-24 01:18:09',
#   None,
#   1.0,
#   None,
#   None,
#   1437762714,
#   0.0),
#  (555,
#   466,
#   'Judy',
#   'Davis-Farash',
#   None,
#   '2014-11-24 07:31:53',
#   None,
#   None,
#   None,
#   None,
#   1437762842,
#   0.0),
#  (556,
#   467,
#   'Peter',
#   'lashenka',
#   None,
#   '2014-11-24 15:49:11',
#   None,
#   None,
#   None,
#   None,
#   1437763150,
#   0.0),
#  (558,
#   468,
#   'jacqueline ',
#   'pari',
#   None,
#   '2014-11-24 16:49:47',
#   None,
#   None,
#   None,
#   None,
#   1437763370,
#   0.0),
#  (559,
#   469,
#   'Robert',
#   'Etienne',
#   None,
#   '2014-11-24 22:20:35',
#   None,
#   1.0,
#   None,
#   None,
#   1437762895,
#   0.0),
#  (560,
#   470,
#   'Robin',
#   'Polanco',
#   None,
#   '2014-11-25 14:40:10',
#   None,
#   None,
#   None,
#   None,
#   1437763408,
#   0.0),
#  (561,
#   471,
#   'Jerald',
#   'Winston',
#   None,
#   '2014-11-25 16:18:11',
#   None,
#   None,
#   None,
#   None,
#   1437764248,
#   0.0),
#  (563,
#   472,
#   'Ronald',
#   'Rains',
#   None,
#   '2014-11-25 18:36:58',
#   None,
#   None,
#   None,
#   None,
#   1437763430,
#   0.0),
#  (564,
#   474,
#   'Lisa',
#   'Zotz',
#   None,
#   '2014-11-26 17:34:05',
#   None,
#   None,
#   None,
#   None,
#   1437764271,
#   0.0),
#  (565,
#   475,
#   'Alma',
#   'evans',
#   None,
#   '2014-11-27 04:51:58',
# ...
#   0.0),
#  (1378,
#   1125,
#   'Joseph',
#   'Potts',
#   None,
#   '2015-06-05 14:48:34',
#   None,
#   None,
#   None,
#   None,
#   1437560245,
#   0.0),
#  (1379,
#   1126,
#   'Luis',
#   'Figueroa',
#   None,
#   '2015-06-05 19:07:50',
#   None,
#   None,
#   None,
#   None,
#   1437559608,
#   0.0),
#  (1380,
#   1131,
#   'Tina',
#   'Eduvie',
#   None,
#   '2015-06-08 14:29:51',
#   None,
#   None,
#   None,
#   None,
#   1437559544,
#   0.0),
#  (1385,
#   1132,
#   'James',
#   'Wolfgang',
#   None,
#   '2015-06-08 14:43:36',
#   None,
#   None,
#   None,
#   None,
#   1437560740,
#   0.0),
#  (1386,
#   1133,
#   'Tommy',
#   'Shirley',
#   None,
#   '2015-06-08 14:50:42',
#   None,
#   1.0,
#   None,
#   None,
#   1437560437,
#   0.0),
#  (1387,
#   1134,
#   'Diane',
#   'Reese',
#   'Company100',
#   '2015-06-08 16:33:22',
#   None,
#   None,
#   None,
#   None,
#   1437560822,
#   0.0),
#  (1388,
#   1136,
#   'V. Catherin',
#   'townsend',
#   None,
#   '2015-06-08 17:37:34',
#   None,
#   1.0,
#   None,
#   None,
#   1437560564,
#   0.0),
#  (1389,
#   1137,
#   'Lou ',
#   'Stallman',
#   None,
#   '2015-06-08 20:05:11',
#   None,
#   None,
#   None,
#   None,
#   1437560470,
#   0.0),
#  (1391,
#   1138,
#   'Jonathan',
#   'Knight',
#   'Company101',
#   '2015-06-09 13:33:56',
#   None,
#   None,
#   None,
#   None,
#   1437560885,
#   0.0),
#  (1392,
#   1139,
#   'Donald',
#   'Karp',
#   None,
#   '2015-06-09 17:35:49',
#   None,
#   1.0,
#   None,
#   None,
#   1437559851,
#   0.0),
#  (1393,
#   1140,
#   'Curtis',
#   'Thompson',
#   None,
#   '2015-06-09 18:13:37',
#   None,
#   1.0,
#   None,
#   None,
#   1437560537,
#   0.0),
#  (1394,
#   1141,
#   'Edward',
#   'Hamilton',
#   None,
#   '2015-06-09 21:14:16',
#   None,
#   1.0,
#   None,
#   None,
#   1437559727,
#   0.0),
#  (1395,
#   1142,
#   'Linda',
#   'Beals',
#   'Company102',
#   '2015-06-10 13:59:50',
#   None,
#   1.0,
#   None,
#   None,
#   1437560952,
#   0.0),
#  (1396,
#   1143,
#   'Joan',
#   'Nash',
#   None,
#   '2015-06-10 14:21:13',
#   None,
#   None,
#   None,
#   None,
#   1437560149,
#   0.0),
#  (1397,
#   1144,
#   'Elizabeth',
#   'Wier',
#   None,
#   '2015-06-10 15:50:37',
#   None,
#   1.0,
#   None,
#   None,
#   1437560696,
#   0.0),
#  (1398,
#   1145,
#   'Columbus area integrated health services inc.',
#   'health services inc',
#   'Company103',
#   '2015-06-10 18:17:18',
#   None,
#   1.0,
#   None,
#   None,
#   1437560830,
#   0.0),
#  (1399,
#   1146,
#   'Janet',
#   'Tyson',
#   None,
#   '2015-06-10 19:35:29',
#   None,
#   None,
#   None,
#   None,
#   1437560592,
#   0.0),
#  (1401,
#   1147,
#   'Rose',
#   'Jones',
#   'Company104',
#   '2015-06-10 19:47:55',
#   None,
#   None,
#   None,
#   None,
#   1437560860,
#   0.0),
#  (1402,
#   1149,
#   'Jennalin',
#   'Wallace',
#   'Company105',
#   '2015-06-10 20:36:17',
#   None,
#   None,
#   None,
#   None,
#   1437560891,
#   0.0),
#  (1403,
#   1151,
#   'Joel',
#   'Mann',
#   None,
#   '2015-06-11 03:19:19',
#   None,
#   1.0,
#   None,
#   None,
#   1437559995,
#   0.0),
#  (1404,
#   1152,
#   'Joey',
#   'Szczepaniak',
#   None,
#   '2015-06-11 04:49:33',
#   None,
#   None,
#   None,
#   None,
#   1437560515,
#   0.0),
#  (1405,
#   1155,
#   'Roy',
#   'Remer',
#   'Company106',
#   '2015-06-11 21:52:13',
#   None,
#   None,
#   None,
#   None,
#   1437560984,
#   0.0),
#  (1406,
#   1156,
#   'Barbara',
#   'Pushis',
#   'Company68',
#   '2015-06-12 01:28:09',
#   None,
#   1.0,
#   None,
#   None,
#   1437560780,
#   0.0),
#  (1408,
#   1157,
#   'Ira',
#   'Rubin',
#   None,
#   '2015-06-12 03:20:34',
#   None,
#   1.0,
#   None,
#   None,
#   1437560366,
#   0.0),
#  (1409,
#   1158,
#   'Qi',
#   'Jing',
#   None,
#   '2015-06-12 14:56:54',
#   None,
#   None,
#   None,
#   None,
#   1437559831,
#   0.0),
#  (1410,
#   1159,
#   'Douglas',
#   'Courtney',
#   None,
#   '2015-06-12 15:28:43',
#   None,
#   1.0,
#   None,
#   None,
#   1437559473,
#   0.0),
#  (1411,
#   1160,
#   'Carmen',
#   'Gamino',
#   None,
#   '2015-06-12 17:25:34',
#   None,
#   None,
#   None,
#   None,
#   1437559647,
#   0.0),
#  (1412,
#   1161,
#   'Barbara',
#   'Halajian',
#   None,
#   '2015-06-12 17:46:34',
#   None,
#   None,
#   None,
#   None,
#   1437559721,
#   0.0),
#  (1414,
#   1162,
#   'Maureen',
#   'Besant-Jones',
#   None,
#   '2015-06-12 22:54:46',
#   None,
#   None,
#   None,
#   None,
#   1437559335,
#   0.0),
#  (1415,
#   1163,
#   'Mark',
#   'Schwab',
#   None,
#   '2015-06-14 17:04:31',
#   None,
#   1.0,
#   None,
#   None,
#   1437560412,
#   0.0),
#  (1416,
#   1167,
#   'Carl Sipe C.O. ',
#   'Buckeye Linen',
#   None,
#   '2015-06-15 15:46:04',
#   None,
#   None,
#   None,
#   None,
#   1437559386,
#   0.0),
#  (1417,
#   1168,
#   'Laura',
#   'Albert',
#   'Company107',
#   '2015-06-15 20:41:30',
#   None,
#   1.0,
#   None,
#   None,
#   1437560841,
#   0.0),
#  (1418,
#   1170,
#   'Diane',
#   'Bryant',
#   None,
#   '2015-06-16 22:41:47',
#   None,
#   1.0,
#   None,
#   None,
#   1437559382,
#   0.0),
#  (1419,
#   1172,
#   'Steven',
#   'Alexander',
#   None,
#   '2015-06-17 21:16:35',
#   None,
#   1.0,
#   None,
#   None,
#   1437559185,
#   0.0),
#  (1420,
#   1174,
#   'shannon ',
#   'horsfall',
#   None,
#   '2015-06-18 14:45:11',
#   None,
#   None,
#   None,
#   None,
#   1437559789,
#   0.0),
#  (1421,
#   1175,
#   'Harry',
#   'Marien',
#   None,
#   '2015-06-18 16:40:00',
#   None,
#   None,
#   None,
#   None,
#   1437560002,
#   0.0),
#  (1422,
#   1176,
#   'Ronda',
#   'Heppner',
#   None,
#   '2015-06-18 22:54:21',
#   None,
#   1.0,
#   None,
#   None,
#   1437559756,
#   0.0),
#  (1423,
#   1177,
#   'Diana',
#   'Paulsen',
#   None,
#   '2015-06-19 18:21:39',
#   None,
#   1.0,
#   None,
#   None,
#   1437560207,
#   0.0),
#  (1424,
#   1179,
#   'robert',
#   'darreff',
#   None,
#   '2015-06-20 01:58:04',
#   None,
#   None,
#   None,
#   None,
#   1437559489,
#   0.0),
#  (1425,
#   1181,
#   'Lesley',
#   'Miller',
#   None,
#   '2015-06-21 22:05:31',
#   None,
#   None,
#   None,
#   None,
#   1437560067,
#   0.0),
#  (1426,
#   1182,
#   'Adrianna',
#   'Mitchell',
#   None,
#   '2015-06-22 15:12:36',
#   None,
#   1.0,
#   None,
#   None,
#   1437560074,
#   0.0),
#  (1428,
#   1183,
#   'Martin',
#   'Sanders DDS',
#   None,
#   '2015-06-22 17:52:38',
#   None,
#   None,
#   None,
#   None,
#   1437560384,
#   0.0),
#  (1429,
#   1184,
#   'Teresa',
#   'Chedwell',
#   None,
#   '2015-06-22 18:34:53',
#   None,
#   1.0,
#   None,
#   None,
#   1437559440,
#   0.0),
#  (1430,
#   1186,
#   'Jacklyn',
#   'Anderson',
#   None,
#   '2015-06-22 21:05:22',
#   None,
#   1.0,
#   None,
#   None,
#   1437559241,
#   0.0),
#  (1431,
#   1187,
#   'Ann',
#   'Budden',
#   None,
#   '2015-06-23 15:04:18',
#   None,
#   None,
#   None,
#   None,
#   1437762743,
#   0.0),
#  (1432,
#   1188,
#   'Susan',
#   'Gorsen',
#   None,
#   '2015-06-23 15:23:31',
#   None,
#   1.0,
#   None,
#   None,
#   1437762985,
#   0.0),
#  (1433,
#   1189,
#   'Cathreine',
#   'Bower',
#   None,
#   '2015-06-23 15:44:02',
#   None,
#   1.0,
#   None,
#   None,
#   1437762718,
#   0.0),
#  (1434,
#   1190,
#   'ruth',
#   'kantrowitz',
#   'Company108',
#   '2015-06-23 16:27:45',
#   None,
#   None,
#   None,
#   None,
#   1437764420,
#   0.0),
#  (1435,
#   1191,
#   'Candace',
#   'Cable',
#   None,
#   '2015-06-23 18:24:31',
#   None,
#   1.0,
#   None,
#   None,
#   1437762750,
#   0.0),
#  (1438,
#   1192,
#   'Doug',
#   'Horner',
#   None,
#   '2015-06-23 18:35:04',
#   None,
#   1.0,
#   None,
#   None,
#   1437763058,
#   0.0),
#  (1439,
#   1193,
#   'Deborah',
#   'Tayler',
#   'Company109',
#   '2015-06-24 02:44:00',
#   None,
#   1.0,
#   None,
#   None,
#   1437764338,
#   0.0),
#  (1440,
#   1195,
#   'Edgar R.',
#   'Torrico',
#   None,
#   '2015-06-24 15:52:24',
#   None,
#   1.0,
#   None,
#   None,
#   1437763635,
#   0.0),
#  (1442,
#   1196,
#   'Denise',
#   'Pizzano',
#   None,
#   '2015-06-24 17:44:13',
#   None,
#   1.0,
#   None,
#   None,
#   1437763404,
#   0.0),
#  (1443,
#   1197,
#   'Elaine',
#   'St.Germain',
#   None,
#   '2015-06-24 19:13:00',
#   None,
#   1.0,
#   None,
#   None,
#   1437763563,
#   0.0),
#  (1444,
#   1198,
#   'Abraham',
#   'Kohen',
#   'Company110',
#   '2015-06-25 04:48:45',
#   None,
#   1.0,
#   None,
#   None,
#   1437764295,
#   0.0),
#  (1445,
#   1199,
#   'Joseph',
#   'Sasen',
#   None,
#   '2015-06-25 14:46:28',
#   None,
#   None,
#   None,
#   None,
#   1437763501,
#   0.0),
#  (1446,
#   1200,
#   'Danielle',
#   'Martin',
#   'Company111',
#   '2015-06-25 15:01:58',
#   None,
#   None,
#   None,
#   None,
#   1437764429,
#   0.0),
#  (1447,
#   1201,
#   'Todd',
#   'Schille',
#   None,
#   '2015-06-25 15:16:05',
#   None,
#   None,
#   None,
#   None,
#   1437763511,
#   0.0),
#  (1448,
#   1202,
#   'Florence',
#   'Beberman',
#   None,
#   '2015-06-25 16:18:26',
#   0.0,
#   1.0,
#   None,
#   None,
#   1437762687,
#   0.0),
#  (1449,
#   1204,
#   'Martha',
#   'Gonzales',
#   None,
#   '2015-06-25 19:24:16',
#   None,
#   1.0,
#   None,
#   None,
#   1437762975,
#   0.0),
#  (1450,
#   1205,
#   'Barbara',
#   'McCaskill',
#   None,
#   '2015-06-25 19:52:28',
#   None,
#   None,
#   None,
#   None,
#   1437763246,
#   0.0),
#  (1451,
#   1208,
#   'Robert',
#   'Morgan',
#   None,
#   '2015-06-25 21:17:29',
#   None,
#   None,
#   None,
#   None,
#   1437763309,
#   0.0),
#  (1452,
#   1209,
#   'Thomas',
#   'Elliott',
#   None,
#   '2015-06-25 22:48:43',
#   None,
#   1.0,
#   None,
#   None,
#   1437762886,
#   0.0),
#  (1453,
#   1210,
#   'Christa',
#   'Dedebant',
#   None,
#   '2015-06-26 02:57:51',
#   None,
#   1.0,
#   None,
#   None,
#   1437762845,
#   0.0),
#  (1461,
#   1211,
#   'Fielder',
#   'Strain',
#   None,
#   '2015-06-26 03:02:45',
#   0.0,
#   1.0,
#   None,
#   None,
#   1437763582,
#   0.0),
#  (1462,
#   1212,
#   'Barbara',
#   'Johns',
#   None,
#   '2015-06-26 16:54:23',
#   None,
#   1.0,
#   None,
#   None,
#   1437763090,
#   0.0),
#  (1463,
#   1213,
#   'Steven',
#   'Melesen',
#   None,
#   '2015-06-26 17:23:09',
#   None,
#   1.0,
#   None,
#   None,
#   1437763267,
#   0.0),
#  (1464,
#   1214,
#   'Stoyanka',
#   'Vranesevich',
#   None,
#   '2015-06-26 18:58:12',
#   None,
#   None,
#   None,
#   None,
#   1437763679,
#   0.0),
#  (1465,
#   1215,
#   'Lori',
#   'OBrien',
#   None,
#   '2015-06-26 22:19:16',
#   None,
#   None,
#   None,
#   None,
#   1437763345,
#   0.0),
#  (1467,
#   1216,
#   'Gloria',
#   'Winfree',
#   None,
#   '2015-06-27 18:01:13',
#   None,
#   1.0,
#   None,
#   None,
#   1437764246,
#   0.0),
#  (1469,
#   1217,
#   'Jean',
#   'Koznarek',
#   None,
#   '2015-06-27 19:48:02',
#   None,
#   None,
#   None,
#   None,
#   1437763127,
#   0.0),
#  (1470,
#   1218,
#   'Martha',
#   'Stokes',
#   None,
#   '2015-06-27 21:21:43',
#   None,
#   1.0,
#   None,
#   None,
#   1437763579,
#   0.0),
#  (1471,
#   1219,
#   'Shirley',
#   'Cavaleri',
#   None,
#   '2015-06-28 02:08:11',
#   None,
#   1.0,
#   None,
#   None,
#   1437762773,
#   0.0),
#  (1472,
#   1220,
#   'Phyllis',
#   'Taylor',
#   None,
#   '2015-06-28 17:35:28',
#   None,
#   None,
#   None,
#   None,
#   1437763609,
#   0.0),
#  (1473,
#   1221,
#   'Tansy',
#   'William',
#   None,
#   '2015-06-28 18:50:43',
#   None,
#   1.0,
#   None,
#   None,
#   1437764223,
#   0.0),
#  (1474,
#   1222,
#   'Sandra',
#   'Brackney',
#   'Company112',
#   '2015-06-29 02:09:52',
#   None,
#   1.0,
#   None,
#   None,
#   1437764280,
#   0.0),
#  (1475,
#   1223,
#   'Vilene',
#   'Meyer',
#   None,
#   '2015-06-29 13:59:39',
#   None,
#   None,
#   None,
#   None,
#   1437763275,
#   0.0),
#  (1476,
#   1224,
#   'Rachel',
#   'Jones',
#   None,
#   '2015-06-29 14:27:47',
#   0.0,
#   1.0,
#   None,
#   None,
#   1437763095,
#   0.0),
#  (1477,
#   1225,
#   'Charlene',
#   'Dye',
#   None,
#   '2015-06-29 18:36:55',
#   None,
#   1.0,
#   None,
#   None,
#   1437762873,
#   0.0),
#  (1478,
#   1226,
#   'Santosh',
#   'Tandon',
#   None,
#   '2015-06-29 19:51:35',
#   None,
#   1.0,
#   None,
#   None,
#   1437763601,
#   0.0),
#  (1479,
#   1228,
#   'Kenneth',
#   'Wingett',
#   None,
#   '2015-06-29 22:14:03',
#   None,
#   1.0,
#   None,
#   None,
#   1437764247,
#   0.0),
#  (1480,
#   1230,
#   'Rita',
#   'Salzman',
#   None,
#   '2015-06-30 13:42:26',
#   None,
#   1.0,
#   None,
#   None,
#   1437763494,
#   0.0),
#  (1481,
#   1231,
#   'Nyanru',
#   'Chen',
#   None,
#   '2015-06-30 18:25:43',
#   0.0,
#   1.0,
#   None,
#   None,
#   1437762789,
#   0.0),
#  (1482,
#   1233,
#   'William',
#   'Johnson',
#   None,
#   '2015-06-30 19:14:36',
#   None,
#   None,
#   None,
#   None,
#   1437763094,
#   0.0),
#  (1483,
#   1234,
#   'Aaron',
#   'Mangum',
#   None,
#   '2015-06-30 19:50:35',
#   None,
#   1.0,
#   None,
#   None,
#   1437763214,
#   0.0),
#  (1484,
#   1235,
#   'H N',
#   'Lacefield',
#   None,
#   '2015-07-01 16:41:50',
#   None,
#   None,
#   None,
#   None,
#   1437763143,
#   0.0),
#  (1485,
#   1236,
#   'Katie',
#   'Martin',
#   None,
#   '2015-07-01 18:00:15',
#   None,
#   None,
#   None,
#   None,
#   1437763226,
#   0.0),
#  (1486,
#   1237,
#   'Kerry',
#   'Harrison',
#   'Company113',
#   '2015-07-01 18:34:53',
#   None,
#   1.0,
#   None,
#   None,
#   1437764421,
#   0.0),
#  (1488,
#   1238,
#   'Mary Alise',
#   'Mortensen',
#   None,
#   '2015-07-01 18:36:37',
#   None,
#   1.0,
#   None,
#   None,
#   1437763311,
#   0.0),
#  (1489,
#   1239,
#   'Isaiah',
#   'Capanang',
#   None,
#   '2015-07-01 20:38:21',
#   None,
#   1.0,
#   None,
#   None,
#   1437762760,
#   0.0),
#  (1490,
#   1240,
#   'Ruth',
#   'Reade',
#   None,
#   '2015-07-01 21:11:16',
#   None,
#   1.0,
#   None,
#   None,
#   1437763436,
#   0.0),
#  (1491,
#   1241,
#   'Kim',
#   'Underdahl',
#   None,
#   '2015-07-02 12:19:47',
#   None,
#   1.0,
#   None,
#   None,
#   1437763656,
#   0.0),
#  (1492,
#   1243,
#   'Joniffer',
#   'Wee',
#   None,
#   '2015-07-02 18:38:55',
#   None,
#   1.0,
#   None,
#   None,
#   1437763703,
#   0.0),
#  (1493,
#   1244,
#   'tomas',
#   'anderkvist',
#   None,
#   '2015-07-02 19:07:55',
#   None,
#   1.0,
#   None,
#   None,
#   1437762641,
#   0.0),
#  (1494,
#   1245,
#   'margaret',
#   'benson',
#   None,
#   '2015-07-03 12:56:20',
#   None,
#   None,
#   None,
#   None,
#   1437762695,
#   0.0),
#  (1495,
#   1246,
#   'Rudy',
#   'Valens',
#   None,
#   '2015-07-03 17:27:54',
#   None,
#   1.0,
#   None,
#   None,
#   1437763659,
#   0.0),
#  (1496,
#   1254,
#   'Marty',
#   'Rogers',
#   None,
#   '2015-07-05 17:26:17',
#   None,
#   None,
#   None,
#   None,
#   1437763466,
#   0.0),
#  (1497,
#   1248,
#   'Tina',
#   'Jennings',
#   'Company114',
#   '2015-07-03 23:50:18',
#   None,
#   1.0,
#   None,
#   None,
#   1437764297,
#   0.0),
#  (1498,
#   1249,
#   'Emily',
#   'Smolik',
#   None,
#   '2015-07-04 13:21:45',
#   None,
#   None,
#   None,
#   None,
#   1437763556,
#   0.0),
#  (1499,
#   1250,
#   'Danny',
#   'Klatt',
#   'Company115',
#   '2015-07-04 16:58:58',
#   None,
#   1.0,
#   None,
#   None,
#   1437764352,
#   0.0),
#  (1500,
#   1251,
#   'Tom',
#   'Singleton',
#   'Company116',
#   '2015-07-04 19:01:25',
#   None,
#   None,
#   None,
#   None,
#   1437764409,
#   0.0),
#  (1501,
#   1253,
#   'Candy',
#   'Thomas',
#   None,
#   '2015-07-04 22:15:49',
#   None,
#   1.0,
#   None,
#   None,
#   1437763612,
#   0.0),
#  (1502,
#   1256,
#   'Nancy',
#   'Lebron',
#   None,
#   '2015-07-05 19:04:23',
#   None,
#   None,
#   None,
#   None,
#   1437763158,
#   0.0),
#  (1503,
#   1257,
#   'Tama',
#   'Babcock',
#   None,
#   '2015-07-05 21:11:16',
#   None,
#   1.0,
#   None,
#   None,
#   1437762666,
#   0.0),
#  (1504,
#   1259,
#   'Victoria',
#   'Zurm',
#   None,
#   '2015-07-06 15:08:06',
#   None,
#   1.0,
#   None,
#   None,
#   1437764274,
#   0.0),
#  (1505,
#   1260,
#   'Phillip ',
#   'Pate',
#   None,
#   '2015-07-06 15:48:49',
#   None,
#   None,
#   None,
#   None,
#   1437763379,
#   0.0),
#  (1506,
#   1261,
#   'David',
#   'Penza',
#   None,
#   '2015-07-06 16:02:47',
#   None,
#   1.0,
#   None,
#   None,
#   1437763385,
#   0.0),
#  (1507,
#   1263,
#   'Loreto',
#   'Torres',
#   None,
#   '2015-07-06 16:33:42',
#   None,
#   None,
#   None,
#   None,
#   1437763631,
#   0.0),
#  (1508,
#   1264,
#   'Indira',
#   'Kavirajan',
#   None,
#   '2015-07-06 16:37:34',
#   None,
#   None,
#   None,
#   None,
#   1437763103,
#   0.0),
#  (1509,
#   1266,
#   'Mulumebt',
#   'Gebremichael-asfaw',
#   None,
#   '2015-07-06 18:17:22',
#   None,
#   None,
#   None,
#   None,
#   1437762962,
#   0.0),
#  (1510,
#   1267,
#   'Nancy',
#   'Conner',
#   None,
#   '2015-07-07 16:09:29',
#   None,
#   1.0,
#   None,
#   None,
#   1437762806,
#   0.0),
#  (1511,
#   1268,
#   'Bob',
#   'Fowler',
#   None,
#   '2015-07-07 16:20:30',
#   None,
#   None,
#   None,
#   None,
#   1437762932,
#   0.0),
#  (1512,
#   1269,
#   'Richerd',
#   'Griffin',
#   None,
#   '2015-07-07 16:53:46',
#   None,
#   1.0,
#   None,
#   None,
#   1437762992,
#   0.0),
#  (1513,
#   1270,
#   'Diane',
#   'Bratt',
#   None,
#   '2015-07-07 17:28:31',
#   None,
#   None,
#   None,
#   None,
#   1437762729,
#   0.0),
#  (1514,
#   1271,
#   'Don',
#   'Zimmet',
#   None,
#   '2015-07-07 17:36:58',
#   None,
#   1.0,
#   None,
#   None,
#   1437764269,
#   0.0),
#  (1515,
#   1272,
#   'Maria Tereca',
#   'Baula',
#   None,
#   '2015-07-08 17:17:58',
#   None,
#   1.0,
#   None,
#   None,
#   1437762685,
#   0.0),
#  (1516,
#   1275,
#   'Arlene',
#   'Salmonson',
#   None,
#   '2015-07-09 14:47:14',
#   None,
#   1.0,
#   None,
#   None,
#   1437763493,
#   0.0),
#  (1517,
#   1276,
#   'Rosemary',
#   'Parsons',
#   None,
#   '2015-07-09 17:02:14',
#   None,
#   1.0,
#   None,
#   None,
#   1437763377,
#   0.0),
#  (1518,
#   1277,
#   'Sergio luiz',
#   'moreira JordÌÄ®ÕÌâå£o',
#   None,
#   '2015-07-10 04:53:43',
#   None,
#   1.0,
#   None,
#   None,
#   1437763307,
#   0.0),
#  (1519,
#   1278,
#   'elizabeth',
#   'roussel',
#   None,
#   '2015-07-10 15:37:23',
#   None,
#   None,
#   None,
#   None,
#   1437763479,
#   0.0),
#  (1520,
#   1279,
#   'Evelin',
#   'frimpong',
#   None,
#   '2015-07-10 15:59:35',
#   0.0,
#   1.0,
#   None,
#   None,
#   1437762935,
#   0.0),
#  (1521,
#   1280,
#   'Howard',
#   'Blair',
#   None,
#   '2015-07-10 18:25:00',
#   None,
#   1.0,
#   None,
#   None,
#   1437762707,
#   0.0),
#  (1522,
#   1281,
#   'Lorraine',
#   'Heali-Russels',
#   None,
#   '2015-07-10 18:38:26',
#   None,
#   1.0,
#   None,
#   None,
#   1437763024,
#   0.0),
#  (1525,
#   1282,
#   'Jean',
#   'Schiltz',
#   None,
#   '2015-07-12 03:04:26',
#   None,
#   1.0,
#   None,
#   None,
#   1437763512,
#   0.0),
#  ...]

# %%
sql = """
SELECT
    c.id AS CustomerID,
    c.fname AS FirstName,
    c.lname AS LastName,
    c.company AS Company,
    c.create_date AS CustomerCreateDate,
    c.status AS CustomerStatus,
    o.order_number AS OrderNumber,
    o.placed_date AS OrderPlacedDate,
    o.currency AS OrderCurrency,
    o.subtotal AS OrderSubtotal,
    o.tax AS OrderTax,
    o.total AS OrderTotal
FROM
    Customers c
    INNER JOIN Orders o ON c.id = o.customer_id
"""

# SQL sorgusunu çalıştırarak verileri DataFrame'e aktarın
dfRFM = pd.read_sql_query(sql, conn)

# %%
dfRFM.head()
# Out:
#    CustomerID FirstName  LastName   Company   CustomerCreateDate  \
# 0         797   Christy      Dill  Company0  2015-03-10 20:18:44
# 1           3      John     Smith  Company1  2013-12-03 16:45:39
# 2           3      John     Smith  Company1  2013-12-03 16:45:39
# 3           4     James  Anderson      None  2013-12-11 16:44:23
# 4           5   Abraham    Pollak  Company3  2013-12-12 15:19:59
#
#    CustomerStatus OrderNumber      OrderPlacedDate OrderCurrency  \
# 0             NaN        3758  2015-03-10 20:24:59           USD
# 1             NaN          23  2013-12-03 17:07:35           USD
# 2             NaN        9531  2015-12-08 19:40:52           USD
# 3             NaN          29  2013-12-11 16:44:23           USD
# 4             0.0        1658  2014-09-10 15:40:55           USD
#
#    OrderSubtotal  OrderTax  OrderTotal
# 0          57.20       0.0       64.29
# 1          20.00       NaN       29.99
# 2          68.78       0.0       78.73
# 3          19.56       0.0       29.55
# 4          14.63       NaN       24.58

# %% [markdown]
# ### RFM Tablosu

# %%
# Bugüne kadar olan zaman fazla çıkacağı için tablodaki en son tarihi baz alabiliriz.

now = latest_date = dfRFM['OrderPlacedDate'].max() + pd.DateOffset(days=1)
now
# Out:
# Timestamp('2016-05-17 17:14:39')

# %%
dfRFM['OrderPlacedDate'] = pd.to_datetime(dfRFM['OrderPlacedDate'])

recency = (now - dfRFM.groupby('CustomerID')['OrderPlacedDate'].max()).dt.days
frequency = dfRFM.groupby('CustomerID')['OrderNumber'].count()
monetary = dfRFM.groupby('CustomerID')['OrderTotal'].sum()

rfm_df = pd.DataFrame({
    'Recency': recency,
    'Frequency': frequency,
    'Monetary': monetary
})

print(rfm_df)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 3               160          2    108.72
# 4               888          1     29.55
# 5               615          3    124.99
# 7               872          1     49.14
# 8               858          1     69.70
# ...             ...        ...       ...
# 3730              1          1     16.06
# 3732              1          1     39.99
# 3733              1          1    989.10
# 3735              1          1    129.99
# 3736              1          1     24.54
#
# [3054 rows x 3 columns]

# %% [markdown]
# ### Clustering

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
km=KMeans()
vis=KElbowVisualizer(km, k=(2,10))
vis.fit(rfm_df)
vis.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
model=KMeans(n_clusters=4)
model=model.fit(rfm_df)

# %%
pred=model.predict(rfm_df)

# %%
rfm_df['cluster']=pred

# %%
silhouette_score(rfm_df,pred)
# Out:
# 0.5639767812285592

# %%
rfm_df.head()
# Out:
#             Recency  Frequency  Monetary  cluster
# CustomerID
# 3               160          2    108.72        0
# 4               888          1     29.55        3
# 5               615          3    124.99        3
# 7               872          1     49.14        3
# 8               858          1     69.70        3

# %%
import seaborn as sns
sns.scatterplot(x=rfm_df['Monetary'], y=rfm_df['Recency'], hue=rfm_df['cluster'], size=rfm_df['Frequency'], palette='Set1');

# %% [markdown]
# ## Sonuç
#
# Özelliklerine göre müşteri sınıflandırılması amacıyla geliştirilen kümeleme modeli sonrasında müşterilerin en uygun 4 gruba ayrıldığı görülmüştür.
